# %% [markdown]
# ### Neural Style Transfer
#
# **Neural Transer Recipe**
#
# Using a content image (e.g. cat photo) and a style image (e.g. Starry Night by Van Gogh) that the user will upload, this method will give the user a combination via neural style transfer.
#
# Uses the pre-trained VGG19 CNN to extract multi-layer features. Content representation is extracted from deeper layers (structure and shapes) and style representation is extracted from shallower layers (texture and colour). Algorithm loop optimises pixels of the generated image to minimise the total loss (calculated using the loss function).
#
# If gpu is available use a larger image size and use loader to perform image transformations i.e. pre-processing for vgg19, used to load the image (also adds a batch dimension [1, 3, H, W]). Use the unloader to reverse normalization to convert tensors back to viewable images, used to save the final stylised image.
#
# The gram matrix measures feature correlations within a layer to capture style, hence encodes texture and colour. N.B. Two images have similar styles if their gram matrices are similar.
#
# Perform feature extraction by running the vgg19 network which ectracts intermediate activations i.e. feature maps at specific layers. Content layer is conv4_2 to caapture structure and style layers conv1_1, conv2_1, conv3_1, conv4_1, conv5_1 to capture texture.
#
# Total loss function is calculated using content and style loss i.e. measures how close generated features are to content features and how close generated Gram matrices are to style Gram matrices, respectively. The total variation loss is used for smoothness and to remove noise.
#
# Optimisation loop:
# 1. Load content and style images
# 2. Load pretrained VGG19
# 3. Extract features and Gram matrices
# 4. Initialize generated image, optimise pixels of this tensor directly
# 5. Define optimizer
# 6. Training loop for n steps which iteratively adjusts pixels of generated to minimize total loss
# 7. Save the final image
#
# Parameters used in the style transfer like content_weight, style_weight, tv_weight can get more or less stylized outputs.
#
# N.B. No epochs since no parameters are being trained and model is pretrained, since only generated image is being optimised. (Training the image not the model) Instead each optimisation step updates generated image tensor.

# %% [markdown]
# TO-DO:
# - try out more style focused approach apart from this version i.e. change parameter weights and optimiser

# %%
import torch    
from torchvision import transforms
from PIL import Image
import torch.optim as optim
import torchvision.models as models
from torchvision.models import VGG19_Weights
import matplotlib.pyplot as plt
from pathlib import Path
import imageio
import numpy as np

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

image_size = 512 if torch.cuda.is_available() else 256  

normalization_mean = [0.485, 0.456, 0.406]
normalization_std = [0.229, 0.224, 0.225]
normalize = transforms.Normalize(mean=normalization_mean,
                                 std=normalization_std)

transform = transforms.Compose([
    transforms.Resize(image_size),              
    transforms.CenterCrop(image_size),          
    transforms.ToTensor(),
    normalize
])

unloader = transforms.Compose([
    transforms.Normalize(
        mean=[0, 0, 0],
        std=[1/0.229, 1/0.224, 1/0.225]),
    transforms.Normalize(
        mean=[-0.485, -0.456, -0.406],
        std=[1, 1, 1]),
    transforms.ToPILImage()
])

def load_image(image_path):
    image = Image.open(image_path).convert('RGB')
    image = transform(image).unsqueeze(0)  # Add batch dimension
    return image.to(device) 

def tensor_to_pil(tensor):
    image = tensor.detach().cpu().clone().squeeze(0)
    image = unloader(image)  
    return image

def save_image(tensor, path):
    image = tensor.detach().cpu().clone().squeeze(0)
    image = image * torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1)
    image = image + torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1)
    image = torch.clamp(image, 0, 1)
    transforms.ToPILImage()(image).save(path)

def save_gif(snapshots, path, duration=0.5):
    frames = [np.array(img) for img in snapshots]
    imageio.mimsave(path, frames, duration=duration)
    print(f"Saved GIF to {path}")

def gram_matrix(tensor):
    # tensor shape: (batch_size=1, channels, height, width)
    b, c, h, w = tensor.size()
    features = tensor.view(c, h * w)      # reshape to (channels, height*width)
    G = torch.mm(features, features.t())  # compute Gram matrix (channels x channels)
    return G / (2 * c * h * w)  

# Load VGG19 model with pre-trained weights 
vgg = models.vgg19(weights=VGG19_Weights.DEFAULT).features.to(device).eval()
for param in vgg.parameters():
    param.requires_grad = False

#content_layer = ['conv4_2']
#style_layers = ['conv_1', 'conv_2', 'conv_3', 'conv_4', 'conv_5']

content_layer = '21' 
style_layers = ['0', '5', '10', '19', '28']

def get_content_feature(image):
    x = image
    for i, layer in enumerate(vgg):
        x = layer(x)
        if str(i) == content_layer:
            return x
        
def get_style_features(image, model, layers):
    features = []
    x = image
    for i, layer in enumerate(model):
        x = layer(x)
        if str(i) in layers:
            features.append(x)
    return features

def compute_content_loss(generated_features, content_features):
    return torch.nn.functional.mse_loss(generated_features, content_features)

def compute_style_loss(generated_features, style_features):
    loss = 0
    for gen_feat, style_feat in zip(generated_features, style_features):
        gram_generated = gram_matrix(gen_feat)
        gram_style = gram_matrix(style_feat)
        loss += torch.nn.functional.mse_loss(gram_generated, gram_style)
    return loss

def run_style_transfer(content_img_path, style_img_path, output_path, num_steps=300,
                    init_from_content=True,
                    snapshot_interval=50,
                    show_progress=True):
    
    # Load images 
    content_img = load_image(content_img_path)
    style_img = load_image(style_img_path)

    # Extract Content and Style features from both images, respectively 
    style_features = get_style_features(style_img, vgg, style_layers)
    content_features = get_content_feature(content_img)

    # Initialize generated image
    if init_from_content:
        generated_img = content_img.clone().to(device).requires_grad_(True)
    else:
        generated_img = torch.randn((1, 3, 512, 512), device=device, requires_grad=True)

    optimizer = optim.LBFGS([generated_img])

    # Loss tracking for graph plot
    losses = {"total": [], "content": [], "style": []}
    current_losses = {"total": None, "content": None, "style": None}
    snapshots = []       # sparse for plotting
    gif_frames = []      # dense for GIF
        
    def closure():
        optimizer.zero_grad()

        # Forward Pass
        gen_content = get_content_feature(generated_img)
        gen_style = get_style_features(generated_img, vgg, style_layers)

        # Compute style and content loss
        c_loss = compute_content_loss(gen_content, content_features)
        s_loss = compute_style_loss(gen_style, style_features)
        s_loss = (1e9*s_loss)

        total_loss = c_loss + s_loss
        total_loss.backward()

        current_losses["total"] = total_loss.item()
        current_losses["content"] = c_loss.item()
        current_losses["style"] = s_loss.item()

        return total_loss

    for step in range(num_steps):
        optimizer.step(closure)

        losses["total"].append(current_losses["total"])
        losses["content"].append(current_losses["content"])
        losses["style"].append(current_losses["style"])

        # GIF
        gif_frames.append(tensor_to_pil(generated_img.detach()))

        # Snapshot plots 
        if step % snapshot_interval == 0 or step == 299:
            snapshots.append(gif_frames[-1])

        if show_progress:
            print(f"Step {step}, Total Loss: {current_losses['total']:.4f}, "
            f"Content Loss: {current_losses['content']:.4f}, "
            f"Style Loss: {current_losses['style']:.4f}")
        
    # Save output 
    with torch.no_grad():
        final_img = generated_img.detach().clone()

    save_image(final_img, output_path)
    print(f"Saved stylised image to {output_path}")

    return output_path, gif_frames, snapshots, snapshot_interval, losses

content_path=Path(r"ref_photos\comino-swimming-snorkeling-malta.jpg")
style_path=Path(r"ref_paintings\Van_Gogh_-_Starry_Night_-_Google_Art_Project.jpg")
output_path=Path(r"generated_images\styled_new_method_test.jpg")

output_path, gif_frames, snapshots, snapshot_interval, losses = run_style_transfer(
    content_img_path=content_path,
    style_img_path=style_path, 
    output_path=output_path,
    num_steps=300,
    snapshot_interval=50,
    show_progress=True
)
# Out:
# cuda
# Step 0, Total Loss: 1905.4945, Content Loss: 57.9202, Style Loss: 1847.5742
# Step 1, Total Loss: 425.9470, Content Loss: 65.2917, Style Loss: 360.6554
# Step 2, Total Loss: 265.5159, Content Loss: 62.5658, Style Loss: 202.9500
# Step 3, Total Loss: 202.0980, Content Loss: 60.7144, Style Loss: 141.3836
# Step 4, Total Loss: 166.9270, Content Loss: 58.9499, Style Loss: 107.9771
# Step 5, Total Loss: 145.0581, Content Loss: 57.9245, Style Loss: 87.1336
# Step 6, Total Loss: 130.1414, Content Loss: 56.8035, Style Loss: 73.3379
# Step 7, Total Loss: 119.4379, Content Loss: 55.8548, Style Loss: 63.5831
# Step 8, Total Loss: 111.6549, Content Loss: 55.0650, Style Loss: 56.5899
# Step 9, Total Loss: 106.2071, Content Loss: 54.4753, Style Loss: 51.7319
# Step 10, Total Loss: 101.7554, Content Loss: 53.8047, Style Loss: 47.9507
# Step 11, Total Loss: 97.8794, Content Loss: 53.3866, Style Loss: 44.4928
# Step 12, Total Loss: 94.6186, Content Loss: 52.9281, Style Loss: 41.6905
# Step 13, Total Loss: 91.8857, Content Loss: 52.5308, Style Loss: 39.3549
# Step 14, Total Loss: 89.2415, Content Loss: 52.1514, Style Loss: 37.0901
# Step 15, Total Loss: 86.9849, Content Loss: 51.8113, Style Loss: 35.1736
# Step 16, Total Loss: 84.9899, Content Loss: 51.5618, Style Loss: 33.4281
# Step 17, Total Loss: 83.2379, Content Loss: 51.2681, Style Loss: 31.9698
# Step 18, Total Loss: 81.7703, Content Loss: 51.0410, Style Loss: 30.7294
# Step 19, Total Loss: 80.3289, Content Loss: 50.7868, Style Loss: 29.5421
# Step 20, Total Loss: 79.0607, Content Loss: 50.5781, Style Loss: 28.4826
# Step 21, Total Loss: 77.9374, Content Loss: 50.3728, Style Loss: 27.5646
# Step 22, Total Loss: 76.9689, Content Loss: 50.1725, Style Loss: 26.7964
# Step 23, Total Loss: 76.1329, Content Loss: 50.0128, Style Loss: 26.1201
# Step 24, Total Loss: 75.3595, Content Loss: 49.8807, Style Loss: 25.4788
# Step 25, Total Loss: 74.6758, Content Loss: 49.7274, Style Loss: 24.9484
# Step 26, Total Loss: 74.0303, Content Loss: 49.5667, Style Loss: 24.4635
# Step 27, Total Loss: 73.4466, Content Loss: 49.4242, Style Loss: 24.0224
# Step 28, Total Loss: 72.9657, Content Loss: 49.3298, Style Loss: 23.6359
# Step 29, Total Loss: 72.4999, Content Loss: 49.2099, Style Loss: 23.2900
# Step 30, Total Loss: 72.0893, Content Loss: 49.0955, Style Loss: 22.9939
# Step 31, Total Loss: 71.6924, Content Loss: 49.0064, Style Loss: 22.6861
# Step 32, Total Loss: 71.3281, Content Loss: 48.9207, Style Loss: 22.4074
# Step 33, Total Loss: 71.0022, Content Loss: 48.8443, Style Loss: 22.1579
# Step 34, Total Loss: 70.6963, Content Loss: 48.7628, Style Loss: 21.9335
# Step 35, Total Loss: 70.4198, Content Loss: 48.6717, Style Loss: 21.7482
# Step 36, Total Loss: 70.1556, Content Loss: 48.5880, Style Loss: 21.5677
# Step 37, Total Loss: 69.9079, Content Loss: 48.5040, Style Loss: 21.4039
# Step 38, Total Loss: 69.6861, Content Loss: 48.4589, Style Loss: 21.2272
# Step 39, Total Loss: 69.4712, Content Loss: 48.3836, Style Loss: 21.0875
# Step 40, Total Loss: 69.2751, Content Loss: 48.3181, Style Loss: 20.9569
# Step 41, Total Loss: 69.0825, Content Loss: 48.2601, Style Loss: 20.8224
# Step 42, Total Loss: 68.9059, Content Loss: 48.2043, Style Loss: 20.7015
# Step 43, Total Loss: 68.7352, Content Loss: 48.1426, Style Loss: 20.5926
# Step 44, Total Loss: 68.5791, Content Loss: 48.0832, Style Loss: 20.4959
# Step 45, Total Loss: 68.4387, Content Loss: 48.0500, Style Loss: 20.3887
# Step 46, Total Loss: 68.2951, Content Loss: 47.9934, Style Loss: 20.3017
# Step 47, Total Loss: 68.1584, Content Loss: 47.9408, Style Loss: 20.2175
# Step 48, Total Loss: 68.0335, Content Loss: 47.9048, Style Loss: 20.1287
# Step 49, Total Loss: 67.9130, Content Loss: 47.8666, Style Loss: 20.0464
# Step 50, Total Loss: 67.8004, Content Loss: 47.8210, Style Loss: 19.9794
# Step 51, Total Loss: 67.6912, Content Loss: 47.7859, Style Loss: 19.9053
# Step 52, Total Loss: 67.5865, Content Loss: 47.7489, Style Loss: 19.8376
# Step 53, Total Loss: 67.4917, Content Loss: 47.7187, Style Loss: 19.7729
# Step 54, Total Loss: 67.4031, Content Loss: 47.6893, Style Loss: 19.7138
# Step 55, Total Loss: 67.3143, Content Loss: 47.6572, Style Loss: 19.6571
# Step 56, Total Loss: 67.2308, Content Loss: 47.6336, Style Loss: 19.5972
# Step 57, Total Loss: 67.1540, Content Loss: 47.6080, Style Loss: 19.5460
# Step 58, Total Loss: 67.0772, Content Loss: 47.5705, Style Loss: 19.5067
# Step 59, Total Loss: 67.0072, Content Loss: 47.5536, Style Loss: 19.4536
# Step 60, Total Loss: 66.9358, Content Loss: 47.5198, Style Loss: 19.4160
# Step 61, Total Loss: 66.8703, Content Loss: 47.4987, Style Loss: 19.3716
# Step 62, Total Loss: 66.8069, Content Loss: 47.4720, Style Loss: 19.3348
# Step 63, Total Loss: 66.7453, Content Loss: 47.4513, Style Loss: 19.2940
# Step 64, Total Loss: 66.6864, Content Loss: 47.4244, Style Loss: 19.2620
# Step 65, Total Loss: 66.6313, Content Loss: 47.4073, Style Loss: 19.2241
# Step 66, Total Loss: 66.5784, Content Loss: 47.3868, Style Loss: 19.1916
# Step 67, Total Loss: 66.5243, Content Loss: 47.3630, Style Loss: 19.1613
# Step 68, Total Loss: 66.4743, Content Loss: 47.3460, Style Loss: 19.1283
# Step 69, Total Loss: 66.4256, Content Loss: 47.3274, Style Loss: 19.0982
# Step 70, Total Loss: 66.3811, Content Loss: 47.3083, Style Loss: 19.0728
# Step 71, Total Loss: 66.3380, Content Loss: 47.2881, Style Loss: 19.0498
# Step 72, Total Loss: 66.2948, Content Loss: 47.2696, Style Loss: 19.0252
# Step 73, Total Loss: 66.2535, Content Loss: 47.2536, Style Loss: 18.9999
# Step 74, Total Loss: 66.2149, Content Loss: 47.2391, Style Loss: 18.9759
# Step 75, Total Loss: 66.1778, Content Loss: 47.2229, Style Loss: 18.9550
# Step 76, Total Loss: 66.1413, Content Loss: 47.2090, Style Loss: 18.9323
# Step 77, Total Loss: 66.1049, Content Loss: 47.1931, Style Loss: 18.9118
# Step 78, Total Loss: 66.0704, Content Loss: 47.1812, Style Loss: 18.8892
# Step 79, Total Loss: 66.0382, Content Loss: 47.1656, Style Loss: 18.8726
# Step 80, Total Loss: 66.0055, Content Loss: 47.1525, Style Loss: 18.8530
# Step 81, Total Loss: 65.9741, Content Loss: 47.1416, Style Loss: 18.8325
# Step 82, Total Loss: 65.9447, Content Loss: 47.1273, Style Loss: 18.8174
# Step 83, Total Loss: 65.9155, Content Loss: 47.1132, Style Loss: 18.8023
# Step 84, Total Loss: 65.8875, Content Loss: 47.1016, Style Loss: 18.7859
# Step 85, Total Loss: 65.8600, Content Loss: 47.0936, Style Loss: 18.7664
# Step 86, Total Loss: 65.8338, Content Loss: 47.0809, Style Loss: 18.7529
# Step 87, Total Loss: 65.8080, Content Loss: 47.0691, Style Loss: 18.7389
# Step 88, Total Loss: 65.7838, Content Loss: 47.0603, Style Loss: 18.7236
# Step 89, Total Loss: 65.7595, Content Loss: 47.0481, Style Loss: 18.7113
# Step 90, Total Loss: 65.7361, Content Loss: 47.0379, Style Loss: 18.6982
# Step 91, Total Loss: 65.7130, Content Loss: 47.0278, Style Loss: 18.6851
# Step 92, Total Loss: 65.6914, Content Loss: 47.0191, Style Loss: 18.6722
# Step 93, Total Loss: 65.6695, Content Loss: 47.0102, Style Loss: 18.6593
# Step 94, Total Loss: 65.6490, Content Loss: 47.0018, Style Loss: 18.6472
# Step 95, Total Loss: 65.6284, Content Loss: 46.9943, Style Loss: 18.6341
# Step 96, Total Loss: 65.6088, Content Loss: 46.9867, Style Loss: 18.6221
# Step 97, Total Loss: 65.5896, Content Loss: 46.9759, Style Loss: 18.6137
# Step 98, Total Loss: 65.5712, Content Loss: 46.9749, Style Loss: 18.5962
# Step 99, Total Loss: 65.5536, Content Loss: 46.9644, Style Loss: 18.5893
# Step 100, Total Loss: 65.5365, Content Loss: 46.9567, Style Loss: 18.5798
# Step 101, Total Loss: 65.5192, Content Loss: 46.9508, Style Loss: 18.5683
# Step 102, Total Loss: 65.5025, Content Loss: 46.9409, Style Loss: 18.5616
# Step 103, Total Loss: 65.4860, Content Loss: 46.9354, Style Loss: 18.5506
# Step 104, Total Loss: 65.4701, Content Loss: 46.9281, Style Loss: 18.5421
# Step 105, Total Loss: 65.4546, Content Loss: 46.9243, Style Loss: 18.5303
# Step 106, Total Loss: 65.4395, Content Loss: 46.9160, Style Loss: 18.5235
# Step 107, Total Loss: 65.4250, Content Loss: 46.9086, Style Loss: 18.5163
# Step 108, Total Loss: 65.4107, Content Loss: 46.9032, Style Loss: 18.5076
# Step 109, Total Loss: 65.3972, Content Loss: 46.8950, Style Loss: 18.5022
# Step 110, Total Loss: 65.3835, Content Loss: 46.8906, Style Loss: 18.4930
# Step 111, Total Loss: 65.3708, Content Loss: 46.8850, Style Loss: 18.4858
# Step 112, Total Loss: 65.3573, Content Loss: 46.8794, Style Loss: 18.4780
# Step 113, Total Loss: 65.3450, Content Loss: 46.8745, Style Loss: 18.4706
# Step 114, Total Loss: 65.3327, Content Loss: 46.8693, Style Loss: 18.4634
# Step 115, Total Loss: 65.3208, Content Loss: 46.8652, Style Loss: 18.4556
# Step 116, Total Loss: 65.3092, Content Loss: 46.8593, Style Loss: 18.4499
# Step 117, Total Loss: 65.2980, Content Loss: 46.8541, Style Loss: 18.4439
# Step 118, Total Loss: 65.2871, Content Loss: 46.8489, Style Loss: 18.4382
# Step 119, Total Loss: 65.2762, Content Loss: 46.8460, Style Loss: 18.4302
# Step 120, Total Loss: 65.2656, Content Loss: 46.8394, Style Loss: 18.4262
# Step 121, Total Loss: 65.2551, Content Loss: 46.8343, Style Loss: 18.4208
# Step 122, Total Loss: 65.2448, Content Loss: 46.8298, Style Loss: 18.4149
# Step 123, Total Loss: 65.2348, Content Loss: 46.8250, Style Loss: 18.4098
# Step 124, Total Loss: 65.2247, Content Loss: 46.8213, Style Loss: 18.4034
# Step 125, Total Loss: 65.2149, Content Loss: 46.8172, Style Loss: 18.3977
# Step 126, Total Loss: 65.2056, Content Loss: 46.8138, Style Loss: 18.3918
# Step 127, Total Loss: 65.1962, Content Loss: 46.8092, Style Loss: 18.3870
# Step 128, Total Loss: 65.1874, Content Loss: 46.8074, Style Loss: 18.3800
# Step 129, Total Loss: 65.1783, Content Loss: 46.8025, Style Loss: 18.3757
# Step 130, Total Loss: 65.1696, Content Loss: 46.7964, Style Loss: 18.3732
# Step 131, Total Loss: 65.1607, Content Loss: 46.7942, Style Loss: 18.3666
# Step 132, Total Loss: 65.1523, Content Loss: 46.7909, Style Loss: 18.3613
# Step 133, Total Loss: 65.1438, Content Loss: 46.7856, Style Loss: 18.3582
# Step 134, Total Loss: 65.1357, Content Loss: 46.7834, Style Loss: 18.3523
# Step 135, Total Loss: 65.1273, Content Loss: 46.7798, Style Loss: 18.3476
# Step 136, Total Loss: 65.1195, Content Loss: 46.7743, Style Loss: 18.3452
# Step 137, Total Loss: 65.1118, Content Loss: 46.7698, Style Loss: 18.3419
# Step 138, Total Loss: 65.1041, Content Loss: 46.7678, Style Loss: 18.3363
# Step 139, Total Loss: 65.0967, Content Loss: 46.7653, Style Loss: 18.3314
# Step 140, Total Loss: 65.0895, Content Loss: 46.7618, Style Loss: 18.3277
# Step 141, Total Loss: 65.0825, Content Loss: 46.7591, Style Loss: 18.3234
# Step 142, Total Loss: 65.0754, Content Loss: 46.7570, Style Loss: 18.3184
# Step 143, Total Loss: 65.0680, Content Loss: 46.7532, Style Loss: 18.3148
# Step 144, Total Loss: 65.0612, Content Loss: 46.7516, Style Loss: 18.3096
# Step 145, Total Loss: 65.0541, Content Loss: 46.7479, Style Loss: 18.3062
# Step 146, Total Loss: 65.0476, Content Loss: 46.7462, Style Loss: 18.3014
# Step 147, Total Loss: 65.0408, Content Loss: 46.7425, Style Loss: 18.2984
# Step 148, Total Loss: 65.0342, Content Loss: 46.7405, Style Loss: 18.2936
# Step 149, Total Loss: 65.0280, Content Loss: 46.7375, Style Loss: 18.2905
# Step 150, Total Loss: 65.0214, Content Loss: 46.7343, Style Loss: 18.2871
# Step 151, Total Loss: 65.0154, Content Loss: 46.7305, Style Loss: 18.2849
# Step 152, Total Loss: 65.0090, Content Loss: 46.7292, Style Loss: 18.2799
# Step 153, Total Loss: 65.0029, Content Loss: 46.7257, Style Loss: 18.2772
# Step 154, Total Loss: 64.9969, Content Loss: 46.7216, Style Loss: 18.2753
# Step 155, Total Loss: 64.9911, Content Loss: 46.7193, Style Loss: 18.2718
# Step 156, Total Loss: 64.9851, Content Loss: 46.7159, Style Loss: 18.2692
# Step 157, Total Loss: 64.9794, Content Loss: 46.7143, Style Loss: 18.2651
# Step 158, Total Loss: 64.9734, Content Loss: 46.7099, Style Loss: 18.2635
# Step 159, Total Loss: 64.9678, Content Loss: 46.7089, Style Loss: 18.2589
# Step 160, Total Loss: 64.9622, Content Loss: 46.7064, Style Loss: 18.2558
# Step 161, Total Loss: 64.9569, Content Loss: 46.7034, Style Loss: 18.2535
# Step 162, Total Loss: 64.9512, Content Loss: 46.7002, Style Loss: 18.2510
# Step 163, Total Loss: 64.9460, Content Loss: 46.6965, Style Loss: 18.2495
# Step 164, Total Loss: 64.9408, Content Loss: 46.6957, Style Loss: 18.2451
# Step 165, Total Loss: 64.9354, Content Loss: 46.6933, Style Loss: 18.2421
# Step 166, Total Loss: 64.9304, Content Loss: 46.6906, Style Loss: 18.2399
# Step 167, Total Loss: 64.9255, Content Loss: 46.6877, Style Loss: 18.2379
# Step 168, Total Loss: 64.9206, Content Loss: 46.6849, Style Loss: 18.2358
# Step 169, Total Loss: 64.9158, Content Loss: 46.6822, Style Loss: 18.2337
# Step 170, Total Loss: 64.9108, Content Loss: 46.6805, Style Loss: 18.2302
# Step 171, Total Loss: 64.9058, Content Loss: 46.6791, Style Loss: 18.2267
# Step 172, Total Loss: 64.9012, Content Loss: 46.6761, Style Loss: 18.2252
# Step 173, Total Loss: 64.8962, Content Loss: 46.6737, Style Loss: 18.2225
# Step 174, Total Loss: 64.8914, Content Loss: 46.6724, Style Loss: 18.2190
# Step 175, Total Loss: 64.8868, Content Loss: 46.6708, Style Loss: 18.2161
# Step 176, Total Loss: 64.8820, Content Loss: 46.6684, Style Loss: 18.2136
# Step 177, Total Loss: 64.8774, Content Loss: 46.6664, Style Loss: 18.2110
# Step 178, Total Loss: 64.8728, Content Loss: 46.6648, Style Loss: 18.2080
# Step 179, Total Loss: 64.8679, Content Loss: 46.6624, Style Loss: 18.2056
# Step 180, Total Loss: 64.8633, Content Loss: 46.6601, Style Loss: 18.2033
# Step 181, Total Loss: 64.8589, Content Loss: 46.6577, Style Loss: 18.2011
# Step 182, Total Loss: 64.8546, Content Loss: 46.6550, Style Loss: 18.1996
# Step 183, Total Loss: 64.8503, Content Loss: 46.6539, Style Loss: 18.1964
# Step 184, Total Loss: 64.8460, Content Loss: 46.6522, Style Loss: 18.1938
# Step 185, Total Loss: 64.8418, Content Loss: 46.6496, Style Loss: 18.1922
# Step 186, Total Loss: 64.8380, Content Loss: 46.6488, Style Loss: 18.1891
# Step 187, Total Loss: 64.8337, Content Loss: 46.6463, Style Loss: 18.1875
# Step 188, Total Loss: 64.8297, Content Loss: 46.6437, Style Loss: 18.1860
# Step 189, Total Loss: 64.8258, Content Loss: 46.6431, Style Loss: 18.1827
# Step 190, Total Loss: 64.8235, Content Loss: 46.6410, Style Loss: 18.1825
# Step 191, Total Loss: 64.8196, Content Loss: 46.6392, Style Loss: 18.1804
# Step 192, Total Loss: 64.8158, Content Loss: 46.6386, Style Loss: 18.1772
# Step 193, Total Loss: 64.8119, Content Loss: 46.6358, Style Loss: 18.1761
# Step 194, Total Loss: 64.8081, Content Loss: 46.6351, Style Loss: 18.1730
# Step 195, Total Loss: 64.8045, Content Loss: 46.6338, Style Loss: 18.1707
# Step 196, Total Loss: 64.8008, Content Loss: 46.6312, Style Loss: 18.1696
# Step 197, Total Loss: 64.7967, Content Loss: 46.6297, Style Loss: 18.1670
# Step 198, Total Loss: 64.7934, Content Loss: 46.6285, Style Loss: 18.1650
# Step 199, Total Loss: 64.7898, Content Loss: 46.6272, Style Loss: 18.1626
# Step 200, Total Loss: 64.7861, Content Loss: 46.6262, Style Loss: 18.1599
# Step 201, Total Loss: 64.7825, Content Loss: 46.6236, Style Loss: 18.1589
# Step 202, Total Loss: 64.7791, Content Loss: 46.6220, Style Loss: 18.1571
# Step 203, Total Loss: 64.7768, Content Loss: 46.6201, Style Loss: 18.1567
# Step 204, Total Loss: 64.7735, Content Loss: 46.6192, Style Loss: 18.1543
# Step 205, Total Loss: 64.7704, Content Loss: 46.6177, Style Loss: 18.1527
# Step 206, Total Loss: 64.7690, Content Loss: 46.6182, Style Loss: 18.1508
# Step 207, Total Loss: 64.7659, Content Loss: 46.6156, Style Loss: 18.1503
# Step 208, Total Loss: 64.7626, Content Loss: 46.6137, Style Loss: 18.1490
# Step 209, Total Loss: 64.7594, Content Loss: 46.6120, Style Loss: 18.1474
# Step 210, Total Loss: 64.7559, Content Loss: 46.6097, Style Loss: 18.1462
# Step 211, Total Loss: 64.7529, Content Loss: 46.6108, Style Loss: 18.1421
# Step 212, Total Loss: 64.7497, Content Loss: 46.6079, Style Loss: 18.1418
# Step 213, Total Loss: 64.7465, Content Loss: 46.6069, Style Loss: 18.1397
# Step 214, Total Loss: 64.7433, Content Loss: 46.6051, Style Loss: 18.1382
# Step 215, Total Loss: 64.7403, Content Loss: 46.6031, Style Loss: 18.1372
# Step 216, Total Loss: 64.7374, Content Loss: 46.6028, Style Loss: 18.1346
# Step 217, Total Loss: 64.7342, Content Loss: 46.6016, Style Loss: 18.1326
# Step 218, Total Loss: 64.7313, Content Loss: 46.5990, Style Loss: 18.1323
# Step 219, Total Loss: 64.7312, Content Loss: 46.5992, Style Loss: 18.1320
# Step 220, Total Loss: 64.7305, Content Loss: 46.5991, Style Loss: 18.1315
# Step 221, Total Loss: 64.7277, Content Loss: 46.5977, Style Loss: 18.1300
# Step 222, Total Loss: 64.7260, Content Loss: 46.5958, Style Loss: 18.1302
# Step 223, Total Loss: 64.7232, Content Loss: 46.5956, Style Loss: 18.1276
# Step 224, Total Loss: 64.7203, Content Loss: 46.5931, Style Loss: 18.1272
# Step 225, Total Loss: 64.7175, Content Loss: 46.5919, Style Loss: 18.1257
# Step 226, Total Loss: 64.7170, Content Loss: 46.5924, Style Loss: 18.1246
# Step 227, Total Loss: 64.7144, Content Loss: 46.5922, Style Loss: 18.1222
# Step 228, Total Loss: 64.7129, Content Loss: 46.5899, Style Loss: 18.1231
# Step 229, Total Loss: 64.7103, Content Loss: 46.5894, Style Loss: 18.1209
# Step 230, Total Loss: 64.7075, Content Loss: 46.5894, Style Loss: 18.1182
# Step 231, Total Loss: 64.7050, Content Loss: 46.5870, Style Loss: 18.1180
# Step 232, Total Loss: 64.7023, Content Loss: 46.5853, Style Loss: 18.1170
# Step 233, Total Loss: 64.7014, Content Loss: 46.5857, Style Loss: 18.1157
# Step 234, Total Loss: 64.6990, Content Loss: 46.5847, Style Loss: 18.1143
# Step 235, Total Loss: 64.6961, Content Loss: 46.5836, Style Loss: 18.1125
# Step 236, Total Loss: 64.6933, Content Loss: 46.5828, Style Loss: 18.1105
# Step 237, Total Loss: 64.6908, Content Loss: 46.5813, Style Loss: 18.1095
# Step 238, Total Loss: 64.6881, Content Loss: 46.5806, Style Loss: 18.1075
# Step 239, Total Loss: 64.6854, Content Loss: 46.5784, Style Loss: 18.1070
# Step 240, Total Loss: 64.6829, Content Loss: 46.5778, Style Loss: 18.1051
# Step 241, Total Loss: 64.6804, Content Loss: 46.5768, Style Loss: 18.1036
# Step 242, Total Loss: 64.6789, Content Loss: 46.5767, Style Loss: 18.1022
# Step 243, Total Loss: 64.6776, Content Loss: 46.5758, Style Loss: 18.1018
# Step 244, Total Loss: 64.6753, Content Loss: 46.5742, Style Loss: 18.1011
# Step 245, Total Loss: 64.6729, Content Loss: 46.5740, Style Loss: 18.0989
# Step 246, Total Loss: 64.6704, Content Loss: 46.5729, Style Loss: 18.0975
# Step 247, Total Loss: 64.6681, Content Loss: 46.5718, Style Loss: 18.0964
# Step 248, Total Loss: 64.6665, Content Loss: 46.5701, Style Loss: 18.0963
# Step 249, Total Loss: 64.6641, Content Loss: 46.5696, Style Loss: 18.0945
# Step 250, Total Loss: 64.6618, Content Loss: 46.5685, Style Loss: 18.0933
# Step 251, Total Loss: 64.6594, Content Loss: 46.5677, Style Loss: 18.0918
# Step 252, Total Loss: 64.6571, Content Loss: 46.5660, Style Loss: 18.0911
# Step 253, Total Loss: 64.6550, Content Loss: 46.5663, Style Loss: 18.0887
# Step 254, Total Loss: 64.6527, Content Loss: 46.5646, Style Loss: 18.0881
# Step 255, Total Loss: 64.6506, Content Loss: 46.5644, Style Loss: 18.0861
# Step 256, Total Loss: 64.6484, Content Loss: 46.5638, Style Loss: 18.0845
# Step 257, Total Loss: 64.6460, Content Loss: 46.5623, Style Loss: 18.0837
# Step 258, Total Loss: 64.6456, Content Loss: 46.5611, Style Loss: 18.0846
# Step 259, Total Loss: 64.6435, Content Loss: 46.5618, Style Loss: 18.0816
# Step 260, Total Loss: 64.6413, Content Loss: 46.5608, Style Loss: 18.0805
# Step 261, Total Loss: 64.6391, Content Loss: 46.5586, Style Loss: 18.0805
# Step 262, Total Loss: 64.6367, Content Loss: 46.5584, Style Loss: 18.0783
# Step 263, Total Loss: 64.6344, Content Loss: 46.5588, Style Loss: 18.0756
# Step 264, Total Loss: 64.6324, Content Loss: 46.5573, Style Loss: 18.0751
# Step 265, Total Loss: 64.6302, Content Loss: 46.5560, Style Loss: 18.0742
# Step 266, Total Loss: 64.6283, Content Loss: 46.5560, Style Loss: 18.0723
# Step 267, Total Loss: 64.6259, Content Loss: 46.5545, Style Loss: 18.0714
# Step 268, Total Loss: 64.6237, Content Loss: 46.5535, Style Loss: 18.0702
# Step 269, Total Loss: 64.6229, Content Loss: 46.5542, Style Loss: 18.0687
# Step 270, Total Loss: 64.6205, Content Loss: 46.5518, Style Loss: 18.0687
# Step 271, Total Loss: 64.6190, Content Loss: 46.5519, Style Loss: 18.0671
# Step 272, Total Loss: 64.6168, Content Loss: 46.5511, Style Loss: 18.0658
# Step 273, Total Loss: 64.6151, Content Loss: 46.5506, Style Loss: 18.0645
# Step 274, Total Loss: 64.6130, Content Loss: 46.5490, Style Loss: 18.0640
# Step 275, Total Loss: 64.6110, Content Loss: 46.5483, Style Loss: 18.0627
# Step 276, Total Loss: 64.6091, Content Loss: 46.5470, Style Loss: 18.0621
# Step 277, Total Loss: 64.6069, Content Loss: 46.5459, Style Loss: 18.0610
# Step 278, Total Loss: 64.6056, Content Loss: 46.5457, Style Loss: 18.0599
# Step 279, Total Loss: 64.6035, Content Loss: 46.5439, Style Loss: 18.0596
# Step 280, Total Loss: 64.6027, Content Loss: 46.5444, Style Loss: 18.0583
# Step 281, Total Loss: 64.6025, Content Loss: 46.5438, Style Loss: 18.0587
# Step 282, Total Loss: 64.6004, Content Loss: 46.5425, Style Loss: 18.0579
# Step 283, Total Loss: 64.5985, Content Loss: 46.5424, Style Loss: 18.0561
# Step 284, Total Loss: 64.5975, Content Loss: 46.5413, Style Loss: 18.0562
# Step 285, Total Loss: 64.5956, Content Loss: 46.5407, Style Loss: 18.0550
# Step 286, Total Loss: 64.5950, Content Loss: 46.5397, Style Loss: 18.0553
# Step 287, Total Loss: 64.5936, Content Loss: 46.5395, Style Loss: 18.0540
# Step 288, Total Loss: 64.5918, Content Loss: 46.5398, Style Loss: 18.0520
# Step 289, Total Loss: 64.5899, Content Loss: 46.5392, Style Loss: 18.0507
# Step 290, Total Loss: 64.5882, Content Loss: 46.5381, Style Loss: 18.0501
# Step 291, Total Loss: 64.5872, Content Loss: 46.5369, Style Loss: 18.0502
# Step 292, Total Loss: 64.5851, Content Loss: 46.5360, Style Loss: 18.0491
# Step 293, Total Loss: 64.5833, Content Loss: 46.5352, Style Loss: 18.0481
# Step 294, Total Loss: 64.5815, Content Loss: 46.5340, Style Loss: 18.0475
# Step 295, Total Loss: 64.5796, Content Loss: 46.5334, Style Loss: 18.0461
# Step 296, Total Loss: 64.5774, Content Loss: 46.5319, Style Loss: 18.0455
# Step 297, Total Loss: 64.5758, Content Loss: 46.5315, Style Loss: 18.0443
# Step 298, Total Loss: 64.5738, Content Loss: 46.5313, Style Loss: 18.0425
# Step 299, Total Loss: 64.5720, Content Loss: 46.5305, Style Loss: 18.0415
# Saved stylised image to generated_images\styled_new_method_test.jpg

# %%
# Output loss plot
plt.figure(figsize=(10, 5))
steps = list(range(len(losses["total"])))
plt.plot(steps, losses["total"], label="Total Loss")
plt.plot(steps, losses["content"], label="Content Loss", alpha=0.7)
plt.plot(steps, losses["style"], label="Style Loss", alpha=0.7)
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.title("Neural Style Transfer Loss")
plt.legend()
plt.grid(True)
plt.show()

# Plot intermediate snapshots
fig, axes = plt.subplots(1, len(snapshots), figsize=(15, 5))
if len(snapshots) == 1:
    axes = [axes]

for i, img in enumerate(snapshots):
    axes[i].imshow(img)
    axes[i].set_title(f"Step {i * snapshot_interval}")
    axes[i].axis("off")

plt.tight_layout()
plt.show()

# Create a gif of the neural style transfer
gif_path = output_path.with_suffix(".gif")
frames = [np.array(img) for img in gif_frames]
imageio.mimsave(gif_path, frames, duration=0.08)
print(f"Saved GIF to {gif_path}")
# Out:
# Saved GIF to generated_images\styled_new_method_test.gif
