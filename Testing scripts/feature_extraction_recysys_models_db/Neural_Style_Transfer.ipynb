# %% [markdown]
# ### Neural Style Transfer
#
# **Neural Transer Recipe**
#
# Using a content image (e.g. cat photo) and a style image (e.g. Starry Night by Van Gogh) that the user will upload, this method will give the user a combination via neural style transfer.
#
# Uses the pre-trained VGG19 CNN to extract multi-layer features. Content representation is extracted from deeper layers (structure and shapes) and style representation is extracted from shallower layers (texture and colour). Algorithm loop optimises pixels of the generated image to minimise the total loss (calculated using the loss function).
#
# If gpu is available use a larger image size and use loader to perform image transformations i.e. pre-processing for vgg19, used to load the image (also adds a batch dimension [1, 3, H, W]). Use the unloader to reverse normalization to convert tensors back to viewable images, used to save the final stylised image.
#
# The gram matrix measures feature correlations within a layer to capture style, hence encodes texture and colour. N.B. Two images have similar styles if their gram matrices are similar.
#
# Perform feature extraction by running the vgg19 network which ectracts intermediate activations i.e. feature maps at specific layers. Content layer is conv4_2 to caapture structure and style layers conv1_1, conv2_1, conv3_1, conv4_1, conv5_1 to capture texture.
#
# Total loss function is calculated using content and style loss i.e. measures how close generated features are to content features and how close generated Gram matrices are to style Gram matrices, respectively. The total variation loss is used for smoothness and to remove noise.
#
# Optimisation loop:
# 1. Load content and style images
# 2. Load pretrained VGG19
# 3. Extract features and Gram matrices
# 4. Initialize generated image, optimise pixels of this tensor directly
# 5. Define optimizer
# 6. Training loop for n steps which iteratively adjusts pixels of generated to minimize total loss
# 7. Save the final image
#
# Parameters used in the style transfer like content_weight, style_weight, tv_weight can get more or less stylized outputs.
#
# N.B. No epochs since no parameters are being trained and model is pretrained, since only generated image is being optimised. (Training the image not the model) Instead each optimisation step updates generated image tensor.

# %% [markdown]
# TO-DO:
# - try out more style focused approach apart from this version i.e. change parameter weights and optimiser

# %%
import torch    
from torchvision import transforms
from PIL import Image
import torch.optim as optim
import torchvision.models as models
from torchvision.models import VGG19_Weights
import matplotlib.pyplot as plt
from pathlib import Path
import imageio
import numpy as np

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

image_size = 512 if torch.cuda.is_available() else 256  

normalization_mean = [0.485, 0.456, 0.406]
normalization_std = [0.229, 0.224, 0.225]
normalize = transforms.Normalize(mean=normalization_mean,
                                 std=normalization_std)

transform = transforms.Compose([
    transforms.Resize(image_size),              
    transforms.CenterCrop(image_size),          
    transforms.ToTensor(),
    normalize
])

unloader = transforms.Compose([
    transforms.Normalize(
        mean=[0, 0, 0],
        std=[1/0.229, 1/0.224, 1/0.225]),
    transforms.Normalize(
        mean=[-0.485, -0.456, -0.406],
        std=[1, 1, 1]),
    transforms.ToPILImage()
])

def load_image(image_path):
    image = Image.open(image_path).convert('RGB')
    image = transform(image).unsqueeze(0)  # Add batch dimension
    return image.to(device) 

def tensor_to_pil(tensor):
    image = tensor.detach().cpu().clone().squeeze(0)
    image = unloader(image)  
    return image

def save_image(tensor, path):
    image = tensor.detach().cpu().clone().squeeze(0)
    image = image * torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1)
    image = image + torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1)
    image = torch.clamp(image, 0, 1)
    transforms.ToPILImage()(image).save(path)

def save_gif(snapshots, path, duration=0.5):
    frames = [np.array(img) for img in snapshots]
    imageio.mimsave(path, frames, duration=duration)
    print(f"Saved GIF to {path}")

def gram_matrix(tensor):
    # tensor shape: (batch_size=1, channels, height, width)
    b, c, h, w = tensor.size()
    features = tensor.view(c, h * w)      # reshape to (channels, height*width)
    G = torch.mm(features, features.t())  # compute Gram matrix (channels x channels)
    return G / (2 * c * h * w)  

# Load VGG19 model with pre-trained weights 
vgg = models.vgg19(weights=VGG19_Weights.DEFAULT).features.to(device).eval()
for param in vgg.parameters():
    param.requires_grad = False

#content_layer = ['conv4_2']
#style_layers = ['conv_1', 'conv_2', 'conv_3', 'conv_4', 'conv_5']

content_layer = '21' 
style_layers = ['0', '5', '10', '19', '28']

def get_content_feature(image):
    x = image
    for i, layer in enumerate(vgg):
        x = layer(x)
        if str(i) == content_layer:
            return x
        
def get_style_features(image, model, layers):
    features = []
    x = image
    for i, layer in enumerate(model):
        x = layer(x)
        if str(i) in layers:
            features.append(x)
    return features

def compute_content_loss(generated_features, content_features):
    return torch.nn.functional.mse_loss(generated_features, content_features)

def compute_style_loss(generated_features, style_features):
    loss = 0
    for gen_feat, style_feat in zip(generated_features, style_features):
        gram_generated = gram_matrix(gen_feat)
        gram_style = gram_matrix(style_feat)
        loss += torch.nn.functional.mse_loss(gram_generated, gram_style)
    return loss

def run_style_transfer(content_img_path, style_img_path, output_path, num_steps=300,
                    init_from_content=True,
                    snapshot_interval=50,
                    show_progress=True):
    
    # Load images 
    content_img = load_image(content_img_path)
    style_img = load_image(style_img_path)

    # Extract Content and Style features from both images, respectively 
    style_features = get_style_features(style_img, vgg, style_layers)
    content_features = get_content_feature(content_img)

    # Initialize generated image
    if init_from_content:
        generated_img = content_img.clone().to(device).requires_grad_(True)
    else:
        generated_img = torch.randn((1, 3, 512, 512), device=device, requires_grad=True)

    optimizer = optim.LBFGS([generated_img])

    # Loss tracking for graph plot
    losses = {"total": [], "content": [], "style": []}
    current_losses = {"total": None, "content": None, "style": None}
    snapshots = []       # sparse for plotting
    gif_frames = []      # dense for GIF
        
    def closure():
        optimizer.zero_grad()

        # Forward Pass
        gen_content = get_content_feature(generated_img)
        gen_style = get_style_features(generated_img, vgg, style_layers)

        # Compute style and content loss
        c_loss = compute_content_loss(gen_content, content_features)
        s_loss = compute_style_loss(gen_style, style_features)
        s_loss = (1e9*s_loss)

        total_loss = c_loss + s_loss
        total_loss.backward()

        current_losses["total"] = total_loss.item()
        current_losses["content"] = c_loss.item()
        current_losses["style"] = s_loss.item()

        return total_loss

    for step in range(num_steps):
        optimizer.step(closure)

        losses["total"].append(current_losses["total"])
        losses["content"].append(current_losses["content"])
        losses["style"].append(current_losses["style"])

        # GIF
        gif_frames.append(tensor_to_pil(generated_img.detach()))

        # Snapshot plots 
        if step % snapshot_interval == 0 or step == 299:
            snapshots.append(gif_frames[-1])

        if show_progress:
            print(f"Step {step}, Total Loss: {current_losses['total']:.4f}, "
            f"Content Loss: {current_losses['content']:.4f}, "
            f"Style Loss: {current_losses['style']:.4f}")
        
    # Save output 
    with torch.no_grad():
        final_img = generated_img.detach().clone()

    save_image(final_img, output_path)
    print(f"Saved stylised image to {output_path}")

    return output_path, gif_frames, snapshots, snapshot_interval, losses

content_path=Path(r"ref_photos\comino-swimming-snorkeling-malta.jpg")
style_path=Path(r"ref_paintings\Van_Gogh_-_Starry_Night_-_Google_Art_Project.jpg")
output_path=Path(r"generated_images\styled_new_method_test.jpg")

output_path, gif_frames, snapshots, snapshot_interval, losses = run_style_transfer(
    content_img_path=content_path,
    style_img_path=style_path, 
    output_path=output_path,
    num_steps=300,
    snapshot_interval=50,
    show_progress=True
)
# Out:
# cuda
# Step 0, Total Loss: 1862.0072, Content Loss: 58.5314, Style Loss: 1803.4757
# Step 1, Total Loss: 443.2568, Content Loss: 65.1087, Style Loss: 378.1482
# Step 2, Total Loss: 269.6986, Content Loss: 62.7515, Style Loss: 206.9472
# Step 3, Total Loss: 203.7535, Content Loss: 60.5522, Style Loss: 143.2013
# Step 4, Total Loss: 168.8860, Content Loss: 59.1281, Style Loss: 109.7579
# Step 5, Total Loss: 145.5786, Content Loss: 57.9417, Style Loss: 87.6369
# Step 6, Total Loss: 129.6014, Content Loss: 56.8568, Style Loss: 72.7446
# Step 7, Total Loss: 119.2684, Content Loss: 55.9969, Style Loss: 63.2715
# Step 8, Total Loss: 111.5206, Content Loss: 55.1796, Style Loss: 56.3410
# Step 9, Total Loss: 105.8410, Content Loss: 54.5166, Style Loss: 51.3244
# Step 10, Total Loss: 101.3421, Content Loss: 53.8953, Style Loss: 47.4468
# Step 11, Total Loss: 97.3999, Content Loss: 53.3989, Style Loss: 44.0010
# Step 12, Total Loss: 94.1603, Content Loss: 52.9690, Style Loss: 41.1913
# Step 13, Total Loss: 91.3014, Content Loss: 52.4643, Style Loss: 38.8372
# Step 14, Total Loss: 88.7439, Content Loss: 52.1514, Style Loss: 36.5926
# Step 15, Total Loss: 86.5070, Content Loss: 51.7995, Style Loss: 34.7075
# Step 16, Total Loss: 84.4860, Content Loss: 51.4716, Style Loss: 33.0144
# Step 17, Total Loss: 82.7561, Content Loss: 51.2071, Style Loss: 31.5489
# Step 18, Total Loss: 81.1902, Content Loss: 50.9285, Style Loss: 30.2616
# Step 19, Total Loss: 79.7912, Content Loss: 50.7047, Style Loss: 29.0866
# Step 20, Total Loss: 78.6139, Content Loss: 50.5178, Style Loss: 28.0960
# Step 21, Total Loss: 77.5208, Content Loss: 50.3091, Style Loss: 27.2117
# Step 22, Total Loss: 76.5351, Content Loss: 50.1082, Style Loss: 26.4270
# Step 23, Total Loss: 75.6731, Content Loss: 49.9365, Style Loss: 25.7366
# Step 24, Total Loss: 74.9212, Content Loss: 49.7651, Style Loss: 25.1561
# Step 25, Total Loss: 74.2093, Content Loss: 49.5912, Style Loss: 24.6181
# Step 26, Total Loss: 73.5594, Content Loss: 49.4371, Style Loss: 24.1223
# Step 27, Total Loss: 72.9753, Content Loss: 49.3010, Style Loss: 23.6743
# Step 28, Total Loss: 72.4596, Content Loss: 49.1752, Style Loss: 23.2845
# Step 29, Total Loss: 71.9747, Content Loss: 49.0477, Style Loss: 22.9271
# Step 30, Total Loss: 71.5272, Content Loss: 48.9250, Style Loss: 22.6021
# Step 31, Total Loss: 71.1224, Content Loss: 48.8253, Style Loss: 22.2972
# Step 32, Total Loss: 70.7789, Content Loss: 48.7339, Style Loss: 22.0450
# Step 33, Total Loss: 70.4628, Content Loss: 48.6347, Style Loss: 21.8281
# Step 34, Total Loss: 70.1571, Content Loss: 48.5613, Style Loss: 21.5957
# Step 35, Total Loss: 69.8754, Content Loss: 48.4859, Style Loss: 21.3895
# Step 36, Total Loss: 69.6169, Content Loss: 48.3985, Style Loss: 21.2183
# Step 37, Total Loss: 69.3674, Content Loss: 48.3193, Style Loss: 21.0481
# Step 38, Total Loss: 69.1408, Content Loss: 48.2636, Style Loss: 20.8772
# Step 39, Total Loss: 68.9302, Content Loss: 48.1901, Style Loss: 20.7401
# Step 40, Total Loss: 68.7318, Content Loss: 48.1372, Style Loss: 20.5946
# Step 41, Total Loss: 68.5466, Content Loss: 48.0771, Style Loss: 20.4695
# Step 42, Total Loss: 68.3783, Content Loss: 48.0206, Style Loss: 20.3577
# Step 43, Total Loss: 68.2235, Content Loss: 47.9705, Style Loss: 20.2529
# Step 44, Total Loss: 68.0719, Content Loss: 47.9217, Style Loss: 20.1502
# Step 45, Total Loss: 67.9314, Content Loss: 47.8814, Style Loss: 20.0500
# Step 46, Total Loss: 67.7978, Content Loss: 47.8386, Style Loss: 19.9592
# Step 47, Total Loss: 67.6779, Content Loss: 47.7932, Style Loss: 19.8847
# Step 48, Total Loss: 67.5660, Content Loss: 47.7557, Style Loss: 19.8103
# Step 49, Total Loss: 67.4510, Content Loss: 47.7197, Style Loss: 19.7313
# Step 50, Total Loss: 67.3465, Content Loss: 47.6879, Style Loss: 19.6586
# Step 51, Total Loss: 67.2448, Content Loss: 47.6432, Style Loss: 19.6016
# Step 52, Total Loss: 67.1480, Content Loss: 47.6199, Style Loss: 19.5281
# Step 53, Total Loss: 67.0529, Content Loss: 47.5862, Style Loss: 19.4668
# Step 54, Total Loss: 66.9665, Content Loss: 47.5572, Style Loss: 19.4093
# Step 55, Total Loss: 66.8864, Content Loss: 47.5325, Style Loss: 19.3539
# Step 56, Total Loss: 66.8075, Content Loss: 47.5060, Style Loss: 19.3015
# Step 57, Total Loss: 66.7264, Content Loss: 47.4797, Style Loss: 19.2467
# Step 58, Total Loss: 66.6538, Content Loss: 47.4467, Style Loss: 19.2071
# Step 59, Total Loss: 66.5829, Content Loss: 47.4257, Style Loss: 19.1572
# Step 60, Total Loss: 66.5167, Content Loss: 47.4021, Style Loss: 19.1147
# Step 61, Total Loss: 66.4514, Content Loss: 47.3787, Style Loss: 19.0727
# Step 62, Total Loss: 66.3898, Content Loss: 47.3501, Style Loss: 19.0397
# Step 63, Total Loss: 66.3296, Content Loss: 47.3362, Style Loss: 18.9934
# Step 64, Total Loss: 66.2693, Content Loss: 47.3106, Style Loss: 18.9587
# Step 65, Total Loss: 66.2148, Content Loss: 47.2895, Style Loss: 18.9253
# Step 66, Total Loss: 66.1634, Content Loss: 47.2708, Style Loss: 18.8926
# Step 67, Total Loss: 66.1133, Content Loss: 47.2478, Style Loss: 18.8655
# Step 68, Total Loss: 66.0653, Content Loss: 47.2311, Style Loss: 18.8341
# Step 69, Total Loss: 66.0172, Content Loss: 47.2116, Style Loss: 18.8057
# Step 70, Total Loss: 65.9704, Content Loss: 47.1885, Style Loss: 18.7819
# Step 71, Total Loss: 65.9283, Content Loss: 47.1746, Style Loss: 18.7537
# Step 72, Total Loss: 65.8863, Content Loss: 47.1579, Style Loss: 18.7285
# Step 73, Total Loss: 65.8468, Content Loss: 47.1435, Style Loss: 18.7033
# Step 74, Total Loss: 65.8083, Content Loss: 47.1278, Style Loss: 18.6804
# Step 75, Total Loss: 65.7714, Content Loss: 47.1110, Style Loss: 18.6604
# Step 76, Total Loss: 65.7361, Content Loss: 47.0979, Style Loss: 18.6382
# Step 77, Total Loss: 65.7026, Content Loss: 47.0857, Style Loss: 18.6169
# Step 78, Total Loss: 65.6709, Content Loss: 47.0782, Style Loss: 18.5927
# Step 79, Total Loss: 65.6401, Content Loss: 47.0643, Style Loss: 18.5758
# Step 80, Total Loss: 65.6108, Content Loss: 47.0536, Style Loss: 18.5572
# Step 81, Total Loss: 65.5811, Content Loss: 47.0458, Style Loss: 18.5353
# Step 82, Total Loss: 65.5522, Content Loss: 47.0311, Style Loss: 18.5211
# Step 83, Total Loss: 65.5247, Content Loss: 47.0157, Style Loss: 18.5090
# Step 84, Total Loss: 65.4981, Content Loss: 47.0023, Style Loss: 18.4958
# Step 85, Total Loss: 65.4719, Content Loss: 46.9957, Style Loss: 18.4762
# Step 86, Total Loss: 65.4476, Content Loss: 46.9874, Style Loss: 18.4602
# Step 87, Total Loss: 65.4236, Content Loss: 46.9771, Style Loss: 18.4465
# Step 88, Total Loss: 65.3995, Content Loss: 46.9667, Style Loss: 18.4328
# Step 89, Total Loss: 65.3764, Content Loss: 46.9569, Style Loss: 18.4195
# Step 90, Total Loss: 65.3549, Content Loss: 46.9471, Style Loss: 18.4078
# Step 91, Total Loss: 65.3337, Content Loss: 46.9414, Style Loss: 18.3923
# Step 92, Total Loss: 65.3126, Content Loss: 46.9312, Style Loss: 18.3814
# Step 93, Total Loss: 65.2926, Content Loss: 46.9225, Style Loss: 18.3701
# Step 94, Total Loss: 65.2732, Content Loss: 46.9149, Style Loss: 18.3583
# Step 95, Total Loss: 65.2545, Content Loss: 46.9050, Style Loss: 18.3496
# Step 96, Total Loss: 65.2370, Content Loss: 46.9016, Style Loss: 18.3354
# Step 97, Total Loss: 65.2192, Content Loss: 46.8944, Style Loss: 18.3247
# Step 98, Total Loss: 65.2027, Content Loss: 46.8876, Style Loss: 18.3150
# Step 99, Total Loss: 65.1855, Content Loss: 46.8810, Style Loss: 18.3045
# Step 100, Total Loss: 65.1686, Content Loss: 46.8737, Style Loss: 18.2949
# Step 101, Total Loss: 65.1529, Content Loss: 46.8682, Style Loss: 18.2847
# Step 102, Total Loss: 65.1376, Content Loss: 46.8619, Style Loss: 18.2757
# Step 103, Total Loss: 65.1222, Content Loss: 46.8545, Style Loss: 18.2677
# Step 104, Total Loss: 65.1076, Content Loss: 46.8486, Style Loss: 18.2590
# Step 105, Total Loss: 65.0932, Content Loss: 46.8401, Style Loss: 18.2531
# Step 106, Total Loss: 65.0791, Content Loss: 46.8346, Style Loss: 18.2445
# Step 107, Total Loss: 65.0657, Content Loss: 46.8282, Style Loss: 18.2376
# Step 108, Total Loss: 65.0527, Content Loss: 46.8234, Style Loss: 18.2293
# Step 109, Total Loss: 65.0400, Content Loss: 46.8167, Style Loss: 18.2234
# Step 110, Total Loss: 65.0274, Content Loss: 46.8134, Style Loss: 18.2140
# Step 111, Total Loss: 65.0153, Content Loss: 46.8081, Style Loss: 18.2072
# Step 112, Total Loss: 65.0031, Content Loss: 46.8049, Style Loss: 18.1982
# Step 113, Total Loss: 64.9914, Content Loss: 46.7985, Style Loss: 18.1929
# Step 114, Total Loss: 64.9799, Content Loss: 46.7949, Style Loss: 18.1850
# Step 115, Total Loss: 64.9685, Content Loss: 46.7893, Style Loss: 18.1792
# Step 116, Total Loss: 64.9580, Content Loss: 46.7839, Style Loss: 18.1741
# Step 117, Total Loss: 64.9469, Content Loss: 46.7800, Style Loss: 18.1670
# Step 118, Total Loss: 64.9362, Content Loss: 46.7752, Style Loss: 18.1610
# Step 119, Total Loss: 64.9256, Content Loss: 46.7699, Style Loss: 18.1557
# Step 120, Total Loss: 64.9155, Content Loss: 46.7675, Style Loss: 18.1480
# Step 121, Total Loss: 64.9055, Content Loss: 46.7625, Style Loss: 18.1430
# Step 122, Total Loss: 64.8955, Content Loss: 46.7558, Style Loss: 18.1397
# Step 123, Total Loss: 64.8856, Content Loss: 46.7526, Style Loss: 18.1331
# Step 124, Total Loss: 64.8760, Content Loss: 46.7465, Style Loss: 18.1294
# Step 125, Total Loss: 64.8665, Content Loss: 46.7421, Style Loss: 18.1244
# Step 126, Total Loss: 64.8570, Content Loss: 46.7383, Style Loss: 18.1187
# Step 127, Total Loss: 64.8479, Content Loss: 46.7333, Style Loss: 18.1146
# Step 128, Total Loss: 64.8390, Content Loss: 46.7299, Style Loss: 18.1091
# Step 129, Total Loss: 64.8303, Content Loss: 46.7265, Style Loss: 18.1038
# Step 130, Total Loss: 64.8215, Content Loss: 46.7211, Style Loss: 18.1004
# Step 131, Total Loss: 64.8130, Content Loss: 46.7170, Style Loss: 18.0960
# Step 132, Total Loss: 64.8048, Content Loss: 46.7122, Style Loss: 18.0925
# Step 133, Total Loss: 64.7965, Content Loss: 46.7094, Style Loss: 18.0871
# Step 134, Total Loss: 64.7884, Content Loss: 46.7064, Style Loss: 18.0820
# Step 135, Total Loss: 64.7807, Content Loss: 46.7020, Style Loss: 18.0787
# Step 136, Total Loss: 64.7729, Content Loss: 46.7007, Style Loss: 18.0722
# Step 137, Total Loss: 64.7653, Content Loss: 46.6948, Style Loss: 18.0705
# Step 138, Total Loss: 64.7580, Content Loss: 46.6932, Style Loss: 18.0648
# Step 139, Total Loss: 64.7508, Content Loss: 46.6891, Style Loss: 18.0617
# Step 140, Total Loss: 64.7439, Content Loss: 46.6850, Style Loss: 18.0589
# Step 141, Total Loss: 64.7366, Content Loss: 46.6819, Style Loss: 18.0547
# Step 142, Total Loss: 64.7298, Content Loss: 46.6794, Style Loss: 18.0504
# Step 143, Total Loss: 64.7232, Content Loss: 46.6757, Style Loss: 18.0475
# Step 144, Total Loss: 64.7165, Content Loss: 46.6720, Style Loss: 18.0445
# Step 145, Total Loss: 64.7100, Content Loss: 46.6691, Style Loss: 18.0409
# Step 146, Total Loss: 64.7035, Content Loss: 46.6665, Style Loss: 18.0370
# Step 147, Total Loss: 64.6971, Content Loss: 46.6640, Style Loss: 18.0331
# Step 148, Total Loss: 64.6910, Content Loss: 46.6621, Style Loss: 18.0289
# Step 149, Total Loss: 64.6845, Content Loss: 46.6586, Style Loss: 18.0259
# Step 150, Total Loss: 64.6785, Content Loss: 46.6576, Style Loss: 18.0209
# Step 151, Total Loss: 64.6724, Content Loss: 46.6540, Style Loss: 18.0184
# Step 152, Total Loss: 64.6665, Content Loss: 46.6526, Style Loss: 18.0139
# Step 153, Total Loss: 64.6604, Content Loss: 46.6505, Style Loss: 18.0099
# Step 154, Total Loss: 64.6546, Content Loss: 46.6469, Style Loss: 18.0077
# Step 155, Total Loss: 64.6487, Content Loss: 46.6450, Style Loss: 18.0037
# Step 156, Total Loss: 64.6429, Content Loss: 46.6450, Style Loss: 17.9979
# Step 157, Total Loss: 64.6375, Content Loss: 46.6424, Style Loss: 17.9951
# Step 158, Total Loss: 64.6319, Content Loss: 46.6398, Style Loss: 17.9922
# Step 159, Total Loss: 64.6267, Content Loss: 46.6382, Style Loss: 17.9885
# Step 160, Total Loss: 64.6216, Content Loss: 46.6370, Style Loss: 17.9847
# Step 161, Total Loss: 64.6164, Content Loss: 46.6334, Style Loss: 17.9831
# Step 162, Total Loss: 64.6113, Content Loss: 46.6294, Style Loss: 17.9819
# Step 163, Total Loss: 64.6061, Content Loss: 46.6268, Style Loss: 17.9793
# Step 164, Total Loss: 64.6009, Content Loss: 46.6242, Style Loss: 17.9767
# Step 165, Total Loss: 64.5959, Content Loss: 46.6242, Style Loss: 17.9717
# Step 166, Total Loss: 64.5906, Content Loss: 46.6216, Style Loss: 17.9691
# Step 167, Total Loss: 64.5856, Content Loss: 46.6201, Style Loss: 17.9655
# Step 168, Total Loss: 64.5808, Content Loss: 46.6169, Style Loss: 17.9639
# Step 169, Total Loss: 64.5758, Content Loss: 46.6155, Style Loss: 17.9603
# Step 170, Total Loss: 64.5710, Content Loss: 46.6121, Style Loss: 17.9589
# Step 171, Total Loss: 64.5660, Content Loss: 46.6085, Style Loss: 17.9575
# Step 172, Total Loss: 64.5612, Content Loss: 46.6080, Style Loss: 17.9532
# Step 173, Total Loss: 64.5565, Content Loss: 46.6059, Style Loss: 17.9506
# Step 174, Total Loss: 64.5521, Content Loss: 46.6037, Style Loss: 17.9484
# Step 175, Total Loss: 64.5474, Content Loss: 46.6021, Style Loss: 17.9453
# Step 176, Total Loss: 64.5430, Content Loss: 46.6001, Style Loss: 17.9429
# Step 177, Total Loss: 64.5386, Content Loss: 46.5980, Style Loss: 17.9406
# Step 178, Total Loss: 64.5341, Content Loss: 46.5965, Style Loss: 17.9376
# Step 179, Total Loss: 64.5297, Content Loss: 46.5944, Style Loss: 17.9353
# Step 180, Total Loss: 64.5254, Content Loss: 46.5928, Style Loss: 17.9326
# Step 181, Total Loss: 64.5212, Content Loss: 46.5917, Style Loss: 17.9295
# Step 182, Total Loss: 64.5194, Content Loss: 46.5899, Style Loss: 17.9294
# Step 183, Total Loss: 64.5154, Content Loss: 46.5874, Style Loss: 17.9280
# Step 184, Total Loss: 64.5111, Content Loss: 46.5858, Style Loss: 17.9253
# Step 185, Total Loss: 64.5070, Content Loss: 46.5832, Style Loss: 17.9238
# Step 186, Total Loss: 64.5028, Content Loss: 46.5811, Style Loss: 17.9217
# Step 187, Total Loss: 64.4988, Content Loss: 46.5795, Style Loss: 17.9193
# Step 188, Total Loss: 64.4948, Content Loss: 46.5790, Style Loss: 17.9158
# Step 189, Total Loss: 64.4907, Content Loss: 46.5760, Style Loss: 17.9147
# Step 190, Total Loss: 64.4870, Content Loss: 46.5742, Style Loss: 17.9128
# Step 191, Total Loss: 64.4830, Content Loss: 46.5737, Style Loss: 17.9093
# Step 192, Total Loss: 64.4792, Content Loss: 46.5697, Style Loss: 17.9096
# Step 193, Total Loss: 64.4756, Content Loss: 46.5676, Style Loss: 17.9080
# Step 194, Total Loss: 64.4719, Content Loss: 46.5658, Style Loss: 17.9061
# Step 195, Total Loss: 64.4680, Content Loss: 46.5642, Style Loss: 17.9037
# Step 196, Total Loss: 64.4642, Content Loss: 46.5637, Style Loss: 17.9005
# Step 197, Total Loss: 64.4606, Content Loss: 46.5618, Style Loss: 17.8989
# Step 198, Total Loss: 64.4572, Content Loss: 46.5592, Style Loss: 17.8980
# Step 199, Total Loss: 64.4534, Content Loss: 46.5581, Style Loss: 17.8953
# Step 200, Total Loss: 64.4500, Content Loss: 46.5563, Style Loss: 17.8938
# Step 201, Total Loss: 64.4474, Content Loss: 46.5547, Style Loss: 17.8927
# Step 202, Total Loss: 64.4447, Content Loss: 46.5522, Style Loss: 17.8925
# Step 203, Total Loss: 64.4428, Content Loss: 46.5536, Style Loss: 17.8893
# Step 204, Total Loss: 64.4396, Content Loss: 46.5493, Style Loss: 17.8903
# Step 205, Total Loss: 64.4365, Content Loss: 46.5484, Style Loss: 17.8881
# Step 206, Total Loss: 64.4331, Content Loss: 46.5490, Style Loss: 17.8841
# Step 207, Total Loss: 64.4297, Content Loss: 46.5469, Style Loss: 17.8828
# Step 208, Total Loss: 64.4267, Content Loss: 46.5465, Style Loss: 17.8802
# Step 209, Total Loss: 64.4247, Content Loss: 46.5450, Style Loss: 17.8797
# Step 210, Total Loss: 64.4215, Content Loss: 46.5438, Style Loss: 17.8776
# Step 211, Total Loss: 64.4184, Content Loss: 46.5420, Style Loss: 17.8764
# Step 212, Total Loss: 64.4153, Content Loss: 46.5417, Style Loss: 17.8736
# Step 213, Total Loss: 64.4147, Content Loss: 46.5428, Style Loss: 17.8720
# Step 214, Total Loss: 64.4124, Content Loss: 46.5410, Style Loss: 17.8714
# Step 215, Total Loss: 64.4120, Content Loss: 46.5397, Style Loss: 17.8723
# Step 216, Total Loss: 64.4120, Content Loss: 46.5398, Style Loss: 17.8722
# Step 217, Total Loss: 64.4090, Content Loss: 46.5382, Style Loss: 17.8708
# Step 218, Total Loss: 64.4059, Content Loss: 46.5370, Style Loss: 17.8689
# Step 219, Total Loss: 64.4027, Content Loss: 46.5346, Style Loss: 17.8681
# Step 220, Total Loss: 64.3997, Content Loss: 46.5337, Style Loss: 17.8660
# Step 221, Total Loss: 64.3965, Content Loss: 46.5326, Style Loss: 17.8639
# Step 222, Total Loss: 64.3935, Content Loss: 46.5303, Style Loss: 17.8632
# Step 223, Total Loss: 64.3904, Content Loss: 46.5300, Style Loss: 17.8605
# Step 224, Total Loss: 64.3875, Content Loss: 46.5288, Style Loss: 17.8588
# Step 225, Total Loss: 64.3850, Content Loss: 46.5279, Style Loss: 17.8571
# Step 226, Total Loss: 64.3821, Content Loss: 46.5268, Style Loss: 17.8553
# Step 227, Total Loss: 64.3794, Content Loss: 46.5258, Style Loss: 17.8536
# Step 228, Total Loss: 64.3775, Content Loss: 46.5241, Style Loss: 17.8534
# Step 229, Total Loss: 64.3745, Content Loss: 46.5232, Style Loss: 17.8513
# Step 230, Total Loss: 64.3718, Content Loss: 46.5221, Style Loss: 17.8497
# Step 231, Total Loss: 64.3691, Content Loss: 46.5216, Style Loss: 17.8475
# Step 232, Total Loss: 64.3661, Content Loss: 46.5199, Style Loss: 17.8461
# Step 233, Total Loss: 64.3635, Content Loss: 46.5200, Style Loss: 17.8435
# Step 234, Total Loss: 64.3606, Content Loss: 46.5184, Style Loss: 17.8422
# Step 235, Total Loss: 64.3604, Content Loss: 46.5176, Style Loss: 17.8427
# Step 236, Total Loss: 64.3598, Content Loss: 46.5182, Style Loss: 17.8416
# Step 237, Total Loss: 64.3592, Content Loss: 46.5171, Style Loss: 17.8421
# Step 238, Total Loss: 64.3566, Content Loss: 46.5163, Style Loss: 17.8404
# Step 239, Total Loss: 64.3539, Content Loss: 46.5162, Style Loss: 17.8377
# Step 240, Total Loss: 64.3513, Content Loss: 46.5144, Style Loss: 17.8368
# Step 241, Total Loss: 64.3487, Content Loss: 46.5126, Style Loss: 17.8361
# Step 242, Total Loss: 64.3461, Content Loss: 46.5119, Style Loss: 17.8342
# Step 243, Total Loss: 64.3435, Content Loss: 46.5115, Style Loss: 17.8320
# Step 244, Total Loss: 64.3410, Content Loss: 46.5094, Style Loss: 17.8317
# Step 245, Total Loss: 64.3386, Content Loss: 46.5094, Style Loss: 17.8292
# Step 246, Total Loss: 64.3360, Content Loss: 46.5084, Style Loss: 17.8276
# Step 247, Total Loss: 64.3355, Content Loss: 46.5081, Style Loss: 17.8274
# Step 248, Total Loss: 64.3329, Content Loss: 46.5062, Style Loss: 17.8268
# Step 249, Total Loss: 64.3306, Content Loss: 46.5059, Style Loss: 17.8246
# Step 250, Total Loss: 64.3280, Content Loss: 46.5044, Style Loss: 17.8236
# Step 251, Total Loss: 64.3255, Content Loss: 46.5039, Style Loss: 17.8217
# Step 252, Total Loss: 64.3230, Content Loss: 46.5027, Style Loss: 17.8204
# Step 253, Total Loss: 64.3205, Content Loss: 46.5014, Style Loss: 17.8191
# Step 254, Total Loss: 64.3183, Content Loss: 46.5011, Style Loss: 17.8172
# Step 255, Total Loss: 64.3157, Content Loss: 46.4998, Style Loss: 17.8159
# Step 256, Total Loss: 64.3134, Content Loss: 46.4984, Style Loss: 17.8150
# Step 257, Total Loss: 64.3108, Content Loss: 46.4974, Style Loss: 17.8134
# Step 258, Total Loss: 64.3085, Content Loss: 46.4958, Style Loss: 17.8127
# Step 259, Total Loss: 64.3065, Content Loss: 46.4962, Style Loss: 17.8104
# Step 260, Total Loss: 64.3042, Content Loss: 46.4947, Style Loss: 17.8096
# Step 261, Total Loss: 64.3019, Content Loss: 46.4939, Style Loss: 17.8080
# Step 262, Total Loss: 64.2994, Content Loss: 46.4928, Style Loss: 17.8066
# Step 263, Total Loss: 64.2971, Content Loss: 46.4925, Style Loss: 17.8046
# Step 264, Total Loss: 64.2948, Content Loss: 46.4901, Style Loss: 17.8046
# Step 265, Total Loss: 64.2925, Content Loss: 46.4894, Style Loss: 17.8031
# Step 266, Total Loss: 64.2902, Content Loss: 46.4885, Style Loss: 17.8017
# Step 267, Total Loss: 64.2879, Content Loss: 46.4871, Style Loss: 17.8008
# Step 268, Total Loss: 64.2856, Content Loss: 46.4868, Style Loss: 17.7988
# Step 269, Total Loss: 64.2834, Content Loss: 46.4857, Style Loss: 17.7977
# Step 270, Total Loss: 64.2811, Content Loss: 46.4848, Style Loss: 17.7963
# Step 271, Total Loss: 64.2789, Content Loss: 46.4839, Style Loss: 17.7949
# Step 272, Total Loss: 64.2767, Content Loss: 46.4829, Style Loss: 17.7938
# Step 273, Total Loss: 64.2745, Content Loss: 46.4828, Style Loss: 17.7917
# Step 274, Total Loss: 64.2722, Content Loss: 46.4802, Style Loss: 17.7920
# Step 275, Total Loss: 64.2700, Content Loss: 46.4798, Style Loss: 17.7902
# Step 276, Total Loss: 64.2698, Content Loss: 46.4792, Style Loss: 17.7906
# Step 277, Total Loss: 64.2695, Content Loss: 46.4795, Style Loss: 17.7900
# Step 278, Total Loss: 64.2676, Content Loss: 46.4790, Style Loss: 17.7885
# Step 279, Total Loss: 64.2653, Content Loss: 46.4777, Style Loss: 17.7877
# Step 280, Total Loss: 64.2632, Content Loss: 46.4761, Style Loss: 17.7871
# Step 281, Total Loss: 64.2610, Content Loss: 46.4748, Style Loss: 17.7862
# Step 282, Total Loss: 64.2596, Content Loss: 46.4749, Style Loss: 17.7847
# Step 283, Total Loss: 64.2575, Content Loss: 46.4734, Style Loss: 17.7841
# Step 284, Total Loss: 64.2555, Content Loss: 46.4731, Style Loss: 17.7824
# Step 285, Total Loss: 64.2535, Content Loss: 46.4715, Style Loss: 17.7820
# Step 286, Total Loss: 64.2515, Content Loss: 46.4704, Style Loss: 17.7812
# Step 287, Total Loss: 64.2495, Content Loss: 46.4690, Style Loss: 17.7805
# Step 288, Total Loss: 64.2491, Content Loss: 46.4696, Style Loss: 17.7795
# Step 289, Total Loss: 64.2471, Content Loss: 46.4687, Style Loss: 17.7784
# Step 290, Total Loss: 64.2451, Content Loss: 46.4673, Style Loss: 17.7778
# Step 291, Total Loss: 64.2433, Content Loss: 46.4676, Style Loss: 17.7757
# Step 292, Total Loss: 64.2414, Content Loss: 46.4659, Style Loss: 17.7755
# Step 293, Total Loss: 64.2396, Content Loss: 46.4664, Style Loss: 17.7732
# Step 294, Total Loss: 64.2376, Content Loss: 46.4649, Style Loss: 17.7727
# Step 295, Total Loss: 64.2355, Content Loss: 46.4626, Style Loss: 17.7729
# Step 296, Total Loss: 64.2346, Content Loss: 46.4635, Style Loss: 17.7712
# Step 297, Total Loss: 64.2328, Content Loss: 46.4621, Style Loss: 17.7707
# Step 298, Total Loss: 64.2309, Content Loss: 46.4611, Style Loss: 17.7698
# Step 299, Total Loss: 64.2307, Content Loss: 46.4613, Style Loss: 17.7693
# Saved stylised image to generated_images\styled_new_method_test.jpg
# Saved GIF to generated_images\styled_new_method_test.gif
# WindowsPath('generated_images/styled_new_method_test.jpg')

# %%
# Output loss plot
plt.figure(figsize=(10, 5))
steps = list(range(len(losses["total"])))
plt.plot(steps, losses["total"], label="Total Loss")
plt.plot(steps, losses["content"], label="Content Loss", alpha=0.7)
plt.plot(steps, losses["style"], label="Style Loss", alpha=0.7)
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.title("Neural Style Transfer Loss")
plt.legend()
plt.grid(True)
plt.show()

# Plot intermediate snapshots
fig, axes = plt.subplots(1, len(snapshots), figsize=(15, 5))
if len(snapshots) == 1:
    axes = [axes]

for i, img in enumerate(snapshots):
    axes[i].imshow(img)
    axes[i].set_title(f"Step {i * snapshot_interval}")
    axes[i].axis("off")

plt.tight_layout()
plt.show()

# Create a gif of the neural style transfer
gif_path = output_path.with_suffix(".gif")
frames = [np.array(img) for img in gif_frames]
imageio.mimsave(gif_path, frames, duration=0.08)
print(f"Saved GIF to {gif_path}")
