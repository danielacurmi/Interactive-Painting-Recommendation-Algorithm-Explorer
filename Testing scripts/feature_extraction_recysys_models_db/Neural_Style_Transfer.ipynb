# %% [markdown]
# ### Neural Style Transfer
#
# **Neural Transer Recipe**
#
# Using a content image (e.g. cat photo) and a style image (e.g. Starry Night by Van Gogh) that the user will upload, this method will give the user a combination via neural style transfer.
#
# Uses the pre-trained VGG19 CNN to extract multi-layer features. Content representation is extracted from deeper layers (structure and shapes) and style representation is extracted from shallower layers (texture and colour). Algorithm loop optimises pixels of the generated image to minimise the total loss (calculated using the loss function).
#
# If gpu is available use a larger image size and use loader to perform image transformations i.e. pre-processing for vgg19, used to load the image (also adds a batch dimension [1, 3, H, W]). Use the unloader to reverse normalization to convert tensors back to viewable images, used to save the final stylised image.
#
# The gram matrix measures feature correlations within a layer to capture style, hence encodes texture and colour. N.B. Two images have similar styles if their gram matrices are similar.
#
# Perform feature extraction by running the vgg19 network which ectracts intermediate activations i.e. feature maps at specific layers. Content layer is conv4_2 to caapture structure and style layers conv1_1, conv2_1, conv3_1, conv4_1, conv5_1 to capture texture.
#
# Total loss function is calculated using content and style loss i.e. measures how close generated features are to content features and how close generated Gram matrices are to style Gram matrices, respectively. The total variation loss is used for smoothness and to remove noise.
#
# Optimisation loop:
# 1. Load content and style images
# 2. Load pretrained VGG19
# 3. Extract features and Gram matrices
# 4. Initialize generated image, optimise pixels of this tensor directly
# 5. Define optimizer
# 6. Training loop for n steps which iteratively adjusts pixels of generated to minimize total loss
# 7. Save the final image
#
# Parameters used in the style transfer like content_weight, style_weight, tv_weight can get more or less stylized outputs.
#
# N.B. No epochs since no parameters are being trained and model is pretrained, since only generated image is being optimised. (Training the image not the model) Instead each optimisation step updates generated image tensor.

# %% [markdown]
# TO-DO:
# - try out more style focused approach apart from this version i.e. change parameter weights and optimiser

# %%
import torch    
from torchvision import transforms
from PIL import Image
import torch.optim as optim
import torchvision.models as models
from torchvision.models import VGG19_Weights
import matplotlib.pyplot as plt
from pathlib import Path
import imageio
import numpy as np

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

image_size = 512 if torch.cuda.is_available() else 256  

normalization_mean = [0.485, 0.456, 0.406]
normalization_std = [0.229, 0.224, 0.225]
normalize = transforms.Normalize(mean=normalization_mean,
                                 std=normalization_std)

transform = transforms.Compose([
    transforms.Resize(image_size),              
    transforms.CenterCrop(image_size),          
    transforms.ToTensor(),
    normalize
])

unloader = transforms.Compose([
    transforms.Normalize(
        mean=[0, 0, 0],
        std=[1/0.229, 1/0.224, 1/0.225]),
    transforms.Normalize(
        mean=[-0.485, -0.456, -0.406],
        std=[1, 1, 1]),
    transforms.ToPILImage()
])

def load_image(image_path):
    image = Image.open(image_path).convert('RGB')
    image = transform(image).unsqueeze(0)  # Add batch dimension
    return image.to(device) 

def tensor_to_pil(tensor):
    image = tensor.detach().cpu().clone().squeeze(0)
    image = unloader(image)  
    return image

def save_image(tensor, path):
    image = tensor.detach().cpu().clone().squeeze(0)
    image = image * torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1)
    image = image + torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1)
    image = torch.clamp(image, 0, 1)
    transforms.ToPILImage()(image).save(path)

def save_gif(snapshots, path, duration=0.5):
    frames = [np.array(img) for img in snapshots]
    imageio.mimsave(path, frames, duration=duration)
    print(f"Saved GIF to {path}")

def gram_matrix(tensor):
    # tensor shape: (batch_size=1, channels, height, width)
    b, c, h, w = tensor.size()
    features = tensor.view(c, h * w)      # reshape to (channels, height*width)
    G = torch.mm(features, features.t())  # compute Gram matrix (channels x channels)
    return G / (2 * c * h * w)  

# Load VGG19 model with pre-trained weights 
vgg = models.vgg19(weights=VGG19_Weights.DEFAULT).features.to(device).eval()
for param in vgg.parameters():
    param.requires_grad = False

#content_layer = ['conv4_2']
#style_layers = ['conv_1', 'conv_2', 'conv_3', 'conv_4', 'conv_5']

content_layer = '21' 
style_layers = ['0', '5', '10', '19', '28']

def get_content_feature(image):
    x = image
    for i, layer in enumerate(vgg):
        x = layer(x)
        if str(i) == content_layer:
            return x
        
def get_style_features(image, model, layers):
    features = []
    x = image
    for i, layer in enumerate(model):
        x = layer(x)
        if str(i) in layers:
            features.append(x)
    return features

def compute_content_loss(generated_features, content_features):
    return torch.nn.functional.mse_loss(generated_features, content_features)

def compute_style_loss(generated_features, style_features):
    loss = 0
    for gen_feat, style_feat in zip(generated_features, style_features):
        gram_generated = gram_matrix(gen_feat)
        gram_style = gram_matrix(style_feat)
        loss += torch.nn.functional.mse_loss(gram_generated, gram_style)
    return loss

def run_style_transfer(content_img_path, style_img_path, output_path, num_steps=300,
                    init_from_content=True,
                    snapshot_interval=50,
                    init_snapshot_interval=5,
                    show_progress=True):
    
    # Load images 
    content_img = load_image(content_img_path)
    style_img = load_image(style_img_path)

    # Extract Content and Style features from both images, respectively 
    style_features = get_style_features(style_img, vgg, style_layers)
    content_features = get_content_feature(content_img)

    # Initialize generated image
    if init_from_content:
        generated_img = content_img.clone().to(device).requires_grad_(True)
    else:
        generated_img = torch.randn((1, 3, 512, 512), device=device, requires_grad=True)

    optimizer = optim.LBFGS([generated_img])

    # Loss tracking for graph plot
    losses = {"total": [], "content": [], "style": []}
    current_losses = {"total": None, "content": None, "style": None}
    snapshots = []       # sparse for plotting
    gif_frames = []      # dense for GIF
    init_snapshots = []
        
    def closure():
        optimizer.zero_grad()

        # Forward Pass
        gen_content = get_content_feature(generated_img)
        gen_style = get_style_features(generated_img, vgg, style_layers)

        # Compute style and content loss
        c_loss = compute_content_loss(gen_content, content_features)
        s_loss = compute_style_loss(gen_style, style_features)
        s_loss = (1e9*s_loss)

        total_loss = c_loss + s_loss
        total_loss.backward()

        current_losses["total"] = total_loss.item()
        current_losses["content"] = c_loss.item()
        current_losses["style"] = s_loss.item()

        return total_loss

    for step in range(num_steps):
        optimizer.step(closure)

        losses["total"].append(current_losses["total"])
        losses["content"].append(current_losses["content"])
        losses["style"].append(current_losses["style"])

        # GIF
        gif_frames.append(tensor_to_pil(generated_img.detach()))

        # Snapshot plots 
        if step % snapshot_interval == 0 or step == 299:
            snapshots.append(gif_frames[-1])

        if step % init_snapshot_interval == 0 and step<=25:
            init_snapshots.append(gif_frames[-1])

        if show_progress:
            print(f"Step {step}, Total Loss: {current_losses['total']:.4f}, "
            f"Content Loss: {current_losses['content']:.4f}, "
            f"Style Loss: {current_losses['style']:.4f}")
        
    # Save output 
    with torch.no_grad():
        final_img = generated_img.detach().clone()

    save_image(final_img, output_path)
    print(f"Saved stylised image to {output_path}")

    return output_path, gif_frames, snapshots, init_snapshots, snapshot_interval, init_snapshot_interval, losses

content_path=Path(r"ref_photos\comino-swimming-snorkeling-malta.jpg")
style_path=Path(r"ref_paintings\Van_Gogh_-_Starry_Night_-_Google_Art_Project.jpg")
output_path=Path(r"generated_images\styled_new_method_test.jpg")

output_path, gif_frames, snapshots, init_snapshots, snapshot_interval, init_snapshot_interval, losses = run_style_transfer(
    content_img_path=content_path,
    style_img_path=style_path, 
    output_path=output_path,
    num_steps=300,
    snapshot_interval=50,
    init_snapshot_interval=5,
    show_progress=True
)
# Out:
# cuda
# Step 0, Total Loss: 1893.0779, Content Loss: 57.9933, Style Loss: 1835.0846
# Step 1, Total Loss: 435.7470, Content Loss: 64.5303, Style Loss: 371.2166
# Step 2, Total Loss: 272.0615, Content Loss: 62.1010, Style Loss: 209.9605
# Step 3, Total Loss: 204.8435, Content Loss: 60.4024, Style Loss: 144.4411
# Step 4, Total Loss: 170.0774, Content Loss: 59.0278, Style Loss: 111.0496
# Step 5, Total Loss: 146.8179, Content Loss: 57.5939, Style Loss: 89.2240
# Step 6, Total Loss: 130.7823, Content Loss: 56.8902, Style Loss: 73.8922
# Step 7, Total Loss: 119.4527, Content Loss: 55.8586, Style Loss: 63.5941
# Step 8, Total Loss: 111.8633, Content Loss: 55.0500, Style Loss: 56.8133
# Step 9, Total Loss: 106.2217, Content Loss: 54.3671, Style Loss: 51.8546
# Step 10, Total Loss: 101.4394, Content Loss: 53.8268, Style Loss: 47.6126
# Step 11, Total Loss: 97.8214, Content Loss: 53.3560, Style Loss: 44.4653
# Step 12, Total Loss: 94.5487, Content Loss: 52.9096, Style Loss: 41.6391
# Step 13, Total Loss: 91.7063, Content Loss: 52.5579, Style Loss: 39.1484
# Step 14, Total Loss: 89.1893, Content Loss: 52.1836, Style Loss: 37.0057
# Step 15, Total Loss: 86.8793, Content Loss: 51.9062, Style Loss: 34.9731
# Step 16, Total Loss: 84.9372, Content Loss: 51.5777, Style Loss: 33.3594
# Step 17, Total Loss: 83.1394, Content Loss: 51.2742, Style Loss: 31.8652
# Step 18, Total Loss: 81.6013, Content Loss: 51.0020, Style Loss: 30.5994
# Step 19, Total Loss: 80.2078, Content Loss: 50.8052, Style Loss: 29.4025
# Step 20, Total Loss: 78.9430, Content Loss: 50.5899, Style Loss: 28.3530
# Step 21, Total Loss: 77.8513, Content Loss: 50.3820, Style Loss: 27.4693
# Step 22, Total Loss: 76.9159, Content Loss: 50.1610, Style Loss: 26.7549
# Step 23, Total Loss: 76.0942, Content Loss: 50.0369, Style Loss: 26.0573
# Step 24, Total Loss: 75.3226, Content Loss: 49.9130, Style Loss: 25.4095
# Step 25, Total Loss: 74.6327, Content Loss: 49.7397, Style Loss: 24.8930
# Step 26, Total Loss: 73.9995, Content Loss: 49.6155, Style Loss: 24.3840
# Step 27, Total Loss: 73.4580, Content Loss: 49.4968, Style Loss: 23.9612
# Step 28, Total Loss: 72.9657, Content Loss: 49.3620, Style Loss: 23.6037
# Step 29, Total Loss: 72.5045, Content Loss: 49.2799, Style Loss: 23.2246
# Step 30, Total Loss: 72.0910, Content Loss: 49.1638, Style Loss: 22.9272
# Step 31, Total Loss: 71.6832, Content Loss: 49.0798, Style Loss: 22.6034
# Step 32, Total Loss: 71.3057, Content Loss: 48.9507, Style Loss: 22.3550
# Step 33, Total Loss: 70.9715, Content Loss: 48.8723, Style Loss: 22.0992
# Step 34, Total Loss: 70.6525, Content Loss: 48.7927, Style Loss: 21.8598
# Step 35, Total Loss: 70.3769, Content Loss: 48.7049, Style Loss: 21.6720
# Step 36, Total Loss: 70.1048, Content Loss: 48.6152, Style Loss: 21.4895
# Step 37, Total Loss: 69.8517, Content Loss: 48.5582, Style Loss: 21.2935
# Step 38, Total Loss: 69.6116, Content Loss: 48.4773, Style Loss: 21.1343
# Step 39, Total Loss: 69.4029, Content Loss: 48.4113, Style Loss: 20.9916
# Step 40, Total Loss: 69.2021, Content Loss: 48.3529, Style Loss: 20.8492
# Step 41, Total Loss: 69.0115, Content Loss: 48.2888, Style Loss: 20.7227
# Step 42, Total Loss: 68.8350, Content Loss: 48.2360, Style Loss: 20.5990
# Step 43, Total Loss: 68.6628, Content Loss: 48.1755, Style Loss: 20.4872
# Step 44, Total Loss: 68.5164, Content Loss: 48.1296, Style Loss: 20.3868
# Step 45, Total Loss: 68.3701, Content Loss: 48.0795, Style Loss: 20.2907
# Step 46, Total Loss: 68.2286, Content Loss: 48.0126, Style Loss: 20.2160
# Step 47, Total Loss: 68.0940, Content Loss: 47.9835, Style Loss: 20.1105
# Step 48, Total Loss: 67.9693, Content Loss: 47.9408, Style Loss: 20.0285
# Step 49, Total Loss: 67.8523, Content Loss: 47.8988, Style Loss: 19.9536
# Step 50, Total Loss: 67.7426, Content Loss: 47.8579, Style Loss: 19.8847
# Step 51, Total Loss: 67.6371, Content Loss: 47.8140, Style Loss: 19.8232
# Step 52, Total Loss: 67.5318, Content Loss: 47.7827, Style Loss: 19.7491
# Step 53, Total Loss: 67.4375, Content Loss: 47.7510, Style Loss: 19.6865
# Step 54, Total Loss: 67.3444, Content Loss: 47.7170, Style Loss: 19.6274
# Step 55, Total Loss: 67.2604, Content Loss: 47.6859, Style Loss: 19.5745
# Step 56, Total Loss: 67.1772, Content Loss: 47.6520, Style Loss: 19.5252
# Step 57, Total Loss: 67.0987, Content Loss: 47.6240, Style Loss: 19.4747
# Step 58, Total Loss: 67.0224, Content Loss: 47.5967, Style Loss: 19.4257
# Step 59, Total Loss: 66.9556, Content Loss: 47.5721, Style Loss: 19.3835
# Step 60, Total Loss: 66.8829, Content Loss: 47.5464, Style Loss: 19.3366
# Step 61, Total Loss: 66.8192, Content Loss: 47.5236, Style Loss: 19.2957
# Step 62, Total Loss: 66.7560, Content Loss: 47.5002, Style Loss: 19.2558
# Step 63, Total Loss: 66.6993, Content Loss: 47.4763, Style Loss: 19.2230
# Step 64, Total Loss: 66.6429, Content Loss: 47.4588, Style Loss: 19.1841
# Step 65, Total Loss: 66.5914, Content Loss: 47.4395, Style Loss: 19.1519
# Step 66, Total Loss: 66.5394, Content Loss: 47.4204, Style Loss: 19.1189
# Step 67, Total Loss: 66.4924, Content Loss: 47.4073, Style Loss: 19.0852
# Step 68, Total Loss: 66.4458, Content Loss: 47.3873, Style Loss: 19.0585
# Step 69, Total Loss: 66.3997, Content Loss: 47.3691, Style Loss: 19.0306
# Step 70, Total Loss: 66.3559, Content Loss: 47.3539, Style Loss: 19.0019
# Step 71, Total Loss: 66.3135, Content Loss: 47.3366, Style Loss: 18.9770
# Step 72, Total Loss: 66.2749, Content Loss: 47.3173, Style Loss: 18.9576
# Step 73, Total Loss: 66.2363, Content Loss: 47.3071, Style Loss: 18.9292
# Step 74, Total Loss: 66.1988, Content Loss: 47.2925, Style Loss: 18.9063
# Step 75, Total Loss: 66.1625, Content Loss: 47.2797, Style Loss: 18.8828
# Step 76, Total Loss: 66.1290, Content Loss: 47.2675, Style Loss: 18.8615
# Step 77, Total Loss: 66.0964, Content Loss: 47.2540, Style Loss: 18.8424
# Step 78, Total Loss: 66.0647, Content Loss: 47.2374, Style Loss: 18.8273
# Step 79, Total Loss: 66.0336, Content Loss: 47.2269, Style Loss: 18.8067
# Step 80, Total Loss: 66.0042, Content Loss: 47.2133, Style Loss: 18.7909
# Step 81, Total Loss: 65.9754, Content Loss: 47.2053, Style Loss: 18.7701
# Step 82, Total Loss: 65.9481, Content Loss: 47.1930, Style Loss: 18.7551
# Step 83, Total Loss: 65.9223, Content Loss: 47.1854, Style Loss: 18.7368
# Step 84, Total Loss: 65.8971, Content Loss: 47.1747, Style Loss: 18.7224
# Step 85, Total Loss: 65.8719, Content Loss: 47.1638, Style Loss: 18.7081
# Step 86, Total Loss: 65.8488, Content Loss: 47.1562, Style Loss: 18.6926
# Step 87, Total Loss: 65.8253, Content Loss: 47.1458, Style Loss: 18.6795
# Step 88, Total Loss: 65.8028, Content Loss: 47.1360, Style Loss: 18.6668
# Step 89, Total Loss: 65.7813, Content Loss: 47.1282, Style Loss: 18.6532
# Step 90, Total Loss: 65.7598, Content Loss: 47.1202, Style Loss: 18.6395
# Step 91, Total Loss: 65.7389, Content Loss: 47.1116, Style Loss: 18.6273
# Step 92, Total Loss: 65.7186, Content Loss: 47.1045, Style Loss: 18.6140
# Step 93, Total Loss: 65.6990, Content Loss: 47.0951, Style Loss: 18.6039
# Step 94, Total Loss: 65.6799, Content Loss: 47.0872, Style Loss: 18.5926
# Step 95, Total Loss: 65.6607, Content Loss: 47.0815, Style Loss: 18.5793
# Step 96, Total Loss: 65.6428, Content Loss: 47.0725, Style Loss: 18.5703
# Step 97, Total Loss: 65.6253, Content Loss: 47.0668, Style Loss: 18.5585
# Step 98, Total Loss: 65.6084, Content Loss: 47.0616, Style Loss: 18.5468
# Step 99, Total Loss: 65.5918, Content Loss: 47.0543, Style Loss: 18.5375
# Step 100, Total Loss: 65.5752, Content Loss: 47.0463, Style Loss: 18.5289
# Step 101, Total Loss: 65.5596, Content Loss: 47.0400, Style Loss: 18.5196
# Step 102, Total Loss: 65.5442, Content Loss: 47.0341, Style Loss: 18.5102
# Step 103, Total Loss: 65.5290, Content Loss: 47.0250, Style Loss: 18.5040
# Step 104, Total Loss: 65.5138, Content Loss: 47.0204, Style Loss: 18.4935
# Step 105, Total Loss: 65.4997, Content Loss: 47.0160, Style Loss: 18.4837
# Step 106, Total Loss: 65.4856, Content Loss: 47.0064, Style Loss: 18.4792
# Step 107, Total Loss: 65.4710, Content Loss: 47.0026, Style Loss: 18.4684
# Step 108, Total Loss: 65.4577, Content Loss: 46.9952, Style Loss: 18.4625
# Step 109, Total Loss: 65.4439, Content Loss: 46.9893, Style Loss: 18.4546
# Step 110, Total Loss: 65.4313, Content Loss: 46.9846, Style Loss: 18.4467
# Step 111, Total Loss: 65.4188, Content Loss: 46.9793, Style Loss: 18.4395
# Step 112, Total Loss: 65.4068, Content Loss: 46.9736, Style Loss: 18.4332
# Step 113, Total Loss: 65.3946, Content Loss: 46.9679, Style Loss: 18.4267
# Step 114, Total Loss: 65.3827, Content Loss: 46.9641, Style Loss: 18.4186
# Step 115, Total Loss: 65.3711, Content Loss: 46.9587, Style Loss: 18.4124
# Step 116, Total Loss: 65.3593, Content Loss: 46.9512, Style Loss: 18.4081
# Step 117, Total Loss: 65.3482, Content Loss: 46.9486, Style Loss: 18.3996
# Step 118, Total Loss: 65.3371, Content Loss: 46.9412, Style Loss: 18.3959
# Step 119, Total Loss: 65.3262, Content Loss: 46.9378, Style Loss: 18.3884
# Step 120, Total Loss: 65.3156, Content Loss: 46.9327, Style Loss: 18.3829
# Step 121, Total Loss: 65.3053, Content Loss: 46.9289, Style Loss: 18.3764
# Step 122, Total Loss: 65.2949, Content Loss: 46.9230, Style Loss: 18.3718
# Step 123, Total Loss: 65.2846, Content Loss: 46.9180, Style Loss: 18.3666
# Step 124, Total Loss: 65.2750, Content Loss: 46.9155, Style Loss: 18.3595
# Step 125, Total Loss: 65.2657, Content Loss: 46.9112, Style Loss: 18.3546
# Step 126, Total Loss: 65.2564, Content Loss: 46.9062, Style Loss: 18.3502
# Step 127, Total Loss: 65.2473, Content Loss: 46.9019, Style Loss: 18.3454
# Step 128, Total Loss: 65.2387, Content Loss: 46.8984, Style Loss: 18.3403
# Step 129, Total Loss: 65.2298, Content Loss: 46.8922, Style Loss: 18.3375
# Step 130, Total Loss: 65.2216, Content Loss: 46.8894, Style Loss: 18.3322
# Step 131, Total Loss: 65.2130, Content Loss: 46.8872, Style Loss: 18.3258
# Step 132, Total Loss: 65.2051, Content Loss: 46.8838, Style Loss: 18.3213
# Step 133, Total Loss: 65.1968, Content Loss: 46.8806, Style Loss: 18.3162
# Step 134, Total Loss: 65.1889, Content Loss: 46.8782, Style Loss: 18.3107
# Step 135, Total Loss: 65.1811, Content Loss: 46.8765, Style Loss: 18.3046
# Step 136, Total Loss: 65.1732, Content Loss: 46.8708, Style Loss: 18.3024
# Step 137, Total Loss: 65.1656, Content Loss: 46.8692, Style Loss: 18.2964
# Step 138, Total Loss: 65.1581, Content Loss: 46.8631, Style Loss: 18.2950
# Step 139, Total Loss: 65.1507, Content Loss: 46.8606, Style Loss: 18.2901
# Step 140, Total Loss: 65.1434, Content Loss: 46.8571, Style Loss: 18.2862
# Step 141, Total Loss: 65.1360, Content Loss: 46.8534, Style Loss: 18.2826
# Step 142, Total Loss: 65.1290, Content Loss: 46.8481, Style Loss: 18.2809
# Step 143, Total Loss: 65.1221, Content Loss: 46.8457, Style Loss: 18.2764
# Step 144, Total Loss: 65.1152, Content Loss: 46.8431, Style Loss: 18.2721
# Step 145, Total Loss: 65.1083, Content Loss: 46.8418, Style Loss: 18.2666
# Step 146, Total Loss: 65.1016, Content Loss: 46.8377, Style Loss: 18.2639
# Step 147, Total Loss: 65.0950, Content Loss: 46.8345, Style Loss: 18.2605
# Step 148, Total Loss: 65.0882, Content Loss: 46.8308, Style Loss: 18.2574
# Step 149, Total Loss: 65.0817, Content Loss: 46.8287, Style Loss: 18.2531
# Step 150, Total Loss: 65.0755, Content Loss: 46.8249, Style Loss: 18.2507
# Step 151, Total Loss: 65.0693, Content Loss: 46.8228, Style Loss: 18.2465
# Step 152, Total Loss: 65.0630, Content Loss: 46.8202, Style Loss: 18.2428
# Step 153, Total Loss: 65.0571, Content Loss: 46.8177, Style Loss: 18.2393
# Step 154, Total Loss: 65.0512, Content Loss: 46.8149, Style Loss: 18.2363
# Step 155, Total Loss: 65.0451, Content Loss: 46.8130, Style Loss: 18.2321
# Step 156, Total Loss: 65.0397, Content Loss: 46.8098, Style Loss: 18.2299
# Step 157, Total Loss: 65.0338, Content Loss: 46.8086, Style Loss: 18.2251
# Step 158, Total Loss: 65.0282, Content Loss: 46.8065, Style Loss: 18.2217
# Step 159, Total Loss: 65.0225, Content Loss: 46.8037, Style Loss: 18.2188
# Step 160, Total Loss: 65.0169, Content Loss: 46.8007, Style Loss: 18.2162
# Step 161, Total Loss: 65.0113, Content Loss: 46.7981, Style Loss: 18.2133
# Step 162, Total Loss: 65.0061, Content Loss: 46.7958, Style Loss: 18.2102
# Step 163, Total Loss: 65.0006, Content Loss: 46.7946, Style Loss: 18.2061
# Step 164, Total Loss: 64.9971, Content Loss: 46.7934, Style Loss: 18.2037
# Step 165, Total Loss: 64.9916, Content Loss: 46.7901, Style Loss: 18.2016
# Step 166, Total Loss: 64.9865, Content Loss: 46.7882, Style Loss: 18.1983
# Step 167, Total Loss: 64.9816, Content Loss: 46.7857, Style Loss: 18.1959
# Step 168, Total Loss: 64.9764, Content Loss: 46.7838, Style Loss: 18.1927
# Step 169, Total Loss: 64.9714, Content Loss: 46.7811, Style Loss: 18.1903
# Step 170, Total Loss: 64.9662, Content Loss: 46.7789, Style Loss: 18.1873
# Step 171, Total Loss: 64.9612, Content Loss: 46.7769, Style Loss: 18.1843
# Step 172, Total Loss: 64.9561, Content Loss: 46.7740, Style Loss: 18.1821
# Step 173, Total Loss: 64.9513, Content Loss: 46.7730, Style Loss: 18.1783
# Step 174, Total Loss: 64.9463, Content Loss: 46.7713, Style Loss: 18.1750
# Step 175, Total Loss: 64.9415, Content Loss: 46.7689, Style Loss: 18.1725
# Step 176, Total Loss: 64.9368, Content Loss: 46.7649, Style Loss: 18.1719
# Step 177, Total Loss: 64.9322, Content Loss: 46.7641, Style Loss: 18.1682
# Step 178, Total Loss: 64.9278, Content Loss: 46.7621, Style Loss: 18.1657
# Step 179, Total Loss: 64.9230, Content Loss: 46.7592, Style Loss: 18.1638
# Step 180, Total Loss: 64.9187, Content Loss: 46.7576, Style Loss: 18.1610
# Step 181, Total Loss: 64.9180, Content Loss: 46.7575, Style Loss: 18.1605
# Step 182, Total Loss: 64.9134, Content Loss: 46.7558, Style Loss: 18.1577
# Step 183, Total Loss: 64.9090, Content Loss: 46.7527, Style Loss: 18.1562
# Step 184, Total Loss: 64.9048, Content Loss: 46.7507, Style Loss: 18.1541
# Step 185, Total Loss: 64.9004, Content Loss: 46.7500, Style Loss: 18.1504
# Step 186, Total Loss: 64.8961, Content Loss: 46.7479, Style Loss: 18.1482
# Step 187, Total Loss: 64.8918, Content Loss: 46.7460, Style Loss: 18.1457
# Step 188, Total Loss: 64.8900, Content Loss: 46.7443, Style Loss: 18.1457
# Step 189, Total Loss: 64.8860, Content Loss: 46.7429, Style Loss: 18.1432
# Step 190, Total Loss: 64.8819, Content Loss: 46.7410, Style Loss: 18.1408
# Step 191, Total Loss: 64.8778, Content Loss: 46.7385, Style Loss: 18.1393
# Step 192, Total Loss: 64.8736, Content Loss: 46.7366, Style Loss: 18.1370
# Step 193, Total Loss: 64.8712, Content Loss: 46.7370, Style Loss: 18.1343
# Step 194, Total Loss: 64.8679, Content Loss: 46.7341, Style Loss: 18.1339
# Step 195, Total Loss: 64.8641, Content Loss: 46.7320, Style Loss: 18.1321
# Step 196, Total Loss: 64.8601, Content Loss: 46.7297, Style Loss: 18.1304
# Step 197, Total Loss: 64.8566, Content Loss: 46.7288, Style Loss: 18.1278
# Step 198, Total Loss: 64.8526, Content Loss: 46.7277, Style Loss: 18.1249
# Step 199, Total Loss: 64.8488, Content Loss: 46.7268, Style Loss: 18.1221
# Step 200, Total Loss: 64.8452, Content Loss: 46.7259, Style Loss: 18.1193
# Step 201, Total Loss: 64.8416, Content Loss: 46.7223, Style Loss: 18.1193
# Step 202, Total Loss: 64.8378, Content Loss: 46.7221, Style Loss: 18.1157
# Step 203, Total Loss: 64.8342, Content Loss: 46.7198, Style Loss: 18.1144
# Step 204, Total Loss: 64.8306, Content Loss: 46.7184, Style Loss: 18.1121
# Step 205, Total Loss: 64.8272, Content Loss: 46.7172, Style Loss: 18.1100
# Step 206, Total Loss: 64.8243, Content Loss: 46.7150, Style Loss: 18.1093
# Step 207, Total Loss: 64.8210, Content Loss: 46.7146, Style Loss: 18.1063
# Step 208, Total Loss: 64.8175, Content Loss: 46.7129, Style Loss: 18.1046
# Step 209, Total Loss: 64.8141, Content Loss: 46.7121, Style Loss: 18.1020
# Step 210, Total Loss: 64.8108, Content Loss: 46.7102, Style Loss: 18.1005
# Step 211, Total Loss: 64.8075, Content Loss: 46.7076, Style Loss: 18.0999
# Step 212, Total Loss: 64.8042, Content Loss: 46.7068, Style Loss: 18.0974
# Step 213, Total Loss: 64.8007, Content Loss: 46.7047, Style Loss: 18.0960
# Step 214, Total Loss: 64.7976, Content Loss: 46.7043, Style Loss: 18.0933
# Step 215, Total Loss: 64.7942, Content Loss: 46.7027, Style Loss: 18.0915
# Step 216, Total Loss: 64.7911, Content Loss: 46.7015, Style Loss: 18.0896
# Step 217, Total Loss: 64.7880, Content Loss: 46.7000, Style Loss: 18.0880
# Step 218, Total Loss: 64.7846, Content Loss: 46.6993, Style Loss: 18.0853
# Step 219, Total Loss: 64.7815, Content Loss: 46.6971, Style Loss: 18.0845
# Step 220, Total Loss: 64.7785, Content Loss: 46.6966, Style Loss: 18.0819
# Step 221, Total Loss: 64.7754, Content Loss: 46.6944, Style Loss: 18.0810
# Step 222, Total Loss: 64.7723, Content Loss: 46.6936, Style Loss: 18.0788
# Step 223, Total Loss: 64.7699, Content Loss: 46.6934, Style Loss: 18.0765
# Step 224, Total Loss: 64.7695, Content Loss: 46.6921, Style Loss: 18.0774
# Step 225, Total Loss: 64.7665, Content Loss: 46.6905, Style Loss: 18.0760
# Step 226, Total Loss: 64.7636, Content Loss: 46.6908, Style Loss: 18.0729
# Step 227, Total Loss: 64.7607, Content Loss: 46.6876, Style Loss: 18.0731
# Step 228, Total Loss: 64.7578, Content Loss: 46.6874, Style Loss: 18.0704
# Step 229, Total Loss: 64.7550, Content Loss: 46.6861, Style Loss: 18.0689
# Step 230, Total Loss: 64.7538, Content Loss: 46.6862, Style Loss: 18.0676
# Step 231, Total Loss: 64.7530, Content Loss: 46.6859, Style Loss: 18.0672
# Step 232, Total Loss: 64.7504, Content Loss: 46.6845, Style Loss: 18.0658
# Step 233, Total Loss: 64.7475, Content Loss: 46.6828, Style Loss: 18.0647
# Step 234, Total Loss: 64.7447, Content Loss: 46.6813, Style Loss: 18.0635
# Step 235, Total Loss: 64.7420, Content Loss: 46.6801, Style Loss: 18.0619
# Step 236, Total Loss: 64.7393, Content Loss: 46.6785, Style Loss: 18.0609
# Step 237, Total Loss: 64.7381, Content Loss: 46.6784, Style Loss: 18.0598
# Step 238, Total Loss: 64.7366, Content Loss: 46.6776, Style Loss: 18.0590
# Step 239, Total Loss: 64.7353, Content Loss: 46.6766, Style Loss: 18.0587
# Step 240, Total Loss: 64.7326, Content Loss: 46.6751, Style Loss: 18.0575
# Step 241, Total Loss: 64.7317, Content Loss: 46.6748, Style Loss: 18.0568
# Step 242, Total Loss: 64.7291, Content Loss: 46.6748, Style Loss: 18.0543
# Step 243, Total Loss: 64.7265, Content Loss: 46.6740, Style Loss: 18.0526
# Step 244, Total Loss: 64.7237, Content Loss: 46.6715, Style Loss: 18.0522
# Step 245, Total Loss: 64.7211, Content Loss: 46.6703, Style Loss: 18.0508
# Step 246, Total Loss: 64.7186, Content Loss: 46.6689, Style Loss: 18.0497
# Step 247, Total Loss: 64.7180, Content Loss: 46.6686, Style Loss: 18.0494
# Step 248, Total Loss: 64.7154, Content Loss: 46.6667, Style Loss: 18.0487
# Step 249, Total Loss: 64.7129, Content Loss: 46.6673, Style Loss: 18.0457
# Step 250, Total Loss: 64.7105, Content Loss: 46.6652, Style Loss: 18.0453
# Step 251, Total Loss: 64.7079, Content Loss: 46.6643, Style Loss: 18.0436
# Step 252, Total Loss: 64.7054, Content Loss: 46.6632, Style Loss: 18.0422
# Step 253, Total Loss: 64.7031, Content Loss: 46.6610, Style Loss: 18.0421
# Step 254, Total Loss: 64.7026, Content Loss: 46.6623, Style Loss: 18.0403
# Step 255, Total Loss: 64.7001, Content Loss: 46.6613, Style Loss: 18.0389
# Step 256, Total Loss: 64.6976, Content Loss: 46.6596, Style Loss: 18.0381
# Step 257, Total Loss: 64.6952, Content Loss: 46.6597, Style Loss: 18.0355
# Step 258, Total Loss: 64.6929, Content Loss: 46.6584, Style Loss: 18.0345
# Step 259, Total Loss: 64.6915, Content Loss: 46.6579, Style Loss: 18.0337
# Step 260, Total Loss: 64.6905, Content Loss: 46.6584, Style Loss: 18.0321
# Step 261, Total Loss: 64.6894, Content Loss: 46.6566, Style Loss: 18.0328
# Step 262, Total Loss: 64.6874, Content Loss: 46.6562, Style Loss: 18.0312
# Step 263, Total Loss: 64.6849, Content Loss: 46.6550, Style Loss: 18.0299
# Step 264, Total Loss: 64.6846, Content Loss: 46.6555, Style Loss: 18.0291
# Step 265, Total Loss: 64.6841, Content Loss: 46.6558, Style Loss: 18.0283
# Step 266, Total Loss: 64.6818, Content Loss: 46.6559, Style Loss: 18.0259
# Step 267, Total Loss: 64.6798, Content Loss: 46.6538, Style Loss: 18.0260
# Step 268, Total Loss: 64.6773, Content Loss: 46.6528, Style Loss: 18.0244
# Step 269, Total Loss: 64.6750, Content Loss: 46.6507, Style Loss: 18.0243
# Step 270, Total Loss: 64.6728, Content Loss: 46.6497, Style Loss: 18.0231
# Step 271, Total Loss: 64.6714, Content Loss: 46.6497, Style Loss: 18.0217
# Step 272, Total Loss: 64.6691, Content Loss: 46.6493, Style Loss: 18.0198
# Step 273, Total Loss: 64.6669, Content Loss: 46.6465, Style Loss: 18.0204
# Step 274, Total Loss: 64.6647, Content Loss: 46.6476, Style Loss: 18.0171
# Step 275, Total Loss: 64.6632, Content Loss: 46.6459, Style Loss: 18.0173
# Step 276, Total Loss: 64.6609, Content Loss: 46.6449, Style Loss: 18.0160
# Step 277, Total Loss: 64.6587, Content Loss: 46.6445, Style Loss: 18.0143
# Step 278, Total Loss: 64.6579, Content Loss: 46.6438, Style Loss: 18.0141
# Step 279, Total Loss: 64.6561, Content Loss: 46.6431, Style Loss: 18.0130
# Step 280, Total Loss: 64.6539, Content Loss: 46.6416, Style Loss: 18.0123
# Step 281, Total Loss: 64.6519, Content Loss: 46.6410, Style Loss: 18.0108
# Step 282, Total Loss: 64.6504, Content Loss: 46.6409, Style Loss: 18.0095
# Step 283, Total Loss: 64.6500, Content Loss: 46.6389, Style Loss: 18.0111
# Step 284, Total Loss: 64.6479, Content Loss: 46.6384, Style Loss: 18.0095
# Step 285, Total Loss: 64.6459, Content Loss: 46.6366, Style Loss: 18.0093
# Step 286, Total Loss: 64.6440, Content Loss: 46.6367, Style Loss: 18.0073
# Step 287, Total Loss: 64.6434, Content Loss: 46.6366, Style Loss: 18.0068
# Step 288, Total Loss: 64.6416, Content Loss: 46.6363, Style Loss: 18.0052
# Step 289, Total Loss: 64.6396, Content Loss: 46.6341, Style Loss: 18.0055
# Step 290, Total Loss: 64.6378, Content Loss: 46.6327, Style Loss: 18.0051
# Step 291, Total Loss: 64.6357, Content Loss: 46.6320, Style Loss: 18.0038
# Step 292, Total Loss: 64.6336, Content Loss: 46.6311, Style Loss: 18.0026
# Step 293, Total Loss: 64.6320, Content Loss: 46.6303, Style Loss: 18.0017
# Step 294, Total Loss: 64.6298, Content Loss: 46.6294, Style Loss: 18.0005
# Step 295, Total Loss: 64.6293, Content Loss: 46.6289, Style Loss: 18.0004
# Step 296, Total Loss: 64.6273, Content Loss: 46.6277, Style Loss: 17.9996
# Step 297, Total Loss: 64.6254, Content Loss: 46.6281, Style Loss: 17.9973
# Step 298, Total Loss: 64.6235, Content Loss: 46.6273, Style Loss: 17.9962
# Step 299, Total Loss: 64.6226, Content Loss: 46.6263, Style Loss: 17.9963
# Saved stylised image to generated_images\styled_new_method_test.jpg

# %%
# Output loss plot
plt.figure(figsize=(10, 5))
steps = list(range(len(losses["total"])))
plt.plot(steps, losses["total"], label="Total Loss")
plt.plot(steps, losses["content"], label="Content Loss", alpha=0.7)
plt.plot(steps, losses["style"], label="Style Loss", alpha=0.7)
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.title("Neural Style Transfer Loss")
plt.legend()
plt.grid(True)
plt.show()

# Plot intermediate snapshots
fig, axes = plt.subplots(1, len(snapshots), figsize=(15, 5))
if len(snapshots) == 1:
    axes = [axes]

plt.title(f"Snapshots at every {snapshot_interval} Steps ")
for i, img in enumerate(snapshots):
    axes[i].imshow(img)
    axes[i].set_title(f"Step {i * snapshot_interval}")
    axes[i].axis("off")

plt.tight_layout()
plt.show()

# Plot initial snapshots
fig, axes = plt.subplots(1, len(init_snapshots), figsize=(15, 5))
if len(init_snapshots) == 1:
    axes = [axes]

plt.title("Initial Steps of Neural Style Transfer")
for i, img in enumerate(init_snapshots):
    axes[i].imshow(img)
    axes[i].set_title(f"Step {i * init_snapshot_interval}")
    axes[i].axis("off")

plt.tight_layout()
plt.show()

# Create a gif of the neural style transfer
gif_path = output_path.with_suffix(".gif")
frames = [np.array(img) for img in gif_frames]
imageio.mimsave(gif_path, frames, duration=0.08)
print(f"Saved GIF to {gif_path}")
# Out:
# Saved GIF to generated_images\styled_new_method_test.gif
