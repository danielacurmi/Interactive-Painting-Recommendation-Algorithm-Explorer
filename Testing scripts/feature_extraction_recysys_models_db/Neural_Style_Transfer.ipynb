# %% [markdown]
# ### Neural Style Transfer
#
# **Neural Transer Recipe**
#
# Using a content image (e.g. cat photo) and a style image (e.g. Starry Night by Van Gogh) that the user will upload, this method will give the user a combination via neural style transfer.
#
# Uses the pre-trained VGG19 CNN to extract multi-layer features. Content representation is extracted from deeper layers (structure and shapes) and style representation is extracted from shallower layers (texture and colour). Algorithm loop optimises pixels of the generated image to minimise the total loss (calculated using the loss function).
#
# If gpu is available use a larger image size and use loader to perform image transformations i.e. pre-processing for vgg19, used to load the image (also adds a batch dimension [1, 3, H, W]). Use the unloader to reverse normalization to convert tensors back to viewable images, used to save the final stylised image.
#
# The gram matrix measures feature correlations within a layer to capture style, hence encodes texture and colour. N.B. Two images have similar styles if their gram matrices are similar.
#
# Perform feature extraction by running the vgg19 network which ectracts intermediate activations i.e. feature maps at specific layers. Content layer is conv4_2 to caapture structure and style layers conv1_1, conv2_1, conv3_1, conv4_1, conv5_1 to capture texture.
#
# Total loss function is calculated using content and style loss i.e. measures how close generated features are to content features and how close generated Gram matrices are to style Gram matrices, respectively. The total variation loss is used for smoothness and to remove noise.
#
# Optimisation loop:
# 1. Load content and style images
# 2. Load pretrained VGG19
# 3. Extract features and Gram matrices
# 4. Initialize generated image, optimise pixels of this tensor directly
# 5. Define optimizer
# 6. Training loop for n steps which iteratively adjusts pixels of generated to minimize total loss
# 7. Save the final image
#
# Parameters used in the style transfer like content_weight, style_weight, tv_weight can get more or less stylized outputs.
#
# N.B. No epochs since no parameters are being trained and model is pretrained, since only generated image is being optimised. (Training the image not the model) Instead each optimisation step updates generated image tensor.

# %% [markdown]
# TO-DO:
# - try out more style focused approach apart from this version i.e. change parameter weights and optimiser

# %%
import torch    
from torchvision import transforms
from PIL import Image
import torch.optim as optim
import torchvision.models as models
from torchvision.models import VGG19_Weights
import matplotlib.pyplot as plt
from pathlib import Path
import imageio
import numpy as np

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

image_size = 512 if torch.cuda.is_available() else 256  

normalization_mean = [0.485, 0.456, 0.406]
normalization_std = [0.229, 0.224, 0.225]
normalize = transforms.Normalize(mean=normalization_mean,
                                 std=normalization_std)

transform = transforms.Compose([
    transforms.Resize(image_size),              
    transforms.CenterCrop(image_size),          
    transforms.ToTensor(),
    normalize
])

unloader = transforms.Compose([
    transforms.Normalize(
        mean=[0, 0, 0],
        std=[1/0.229, 1/0.224, 1/0.225]),
    transforms.Normalize(
        mean=[-0.485, -0.456, -0.406],
        std=[1, 1, 1]),
    transforms.ToPILImage()
])

def load_image(image_path):
    image = Image.open(image_path).convert('RGB')
    image = transform(image).unsqueeze(0)  # Add batch dimension
    return image.to(device) 

def tensor_to_pil(tensor):
    image = tensor.detach().cpu().clone().squeeze(0)
    image = torch.clamp(image, 0, 1)  # ensure valid pixel range AFTER unnormalization
    return unloader(image)

def save_image(tensor, path):
    image = tensor.detach().cpu().clone().squeeze(0)
    image = image * torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1)
    image = image + torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1)
    image = torch.clamp(image, 0, 1)
    transforms.ToPILImage()(image).save(path)

def save_gif(snapshots, path, duration=0.5):
    frames = [np.array(img) for img in snapshots]
    imageio.mimsave(path, frames, duration=duration)
    print(f"Saved GIF to {path}")

def gram_matrix(tensor):
    # tensor shape: (batch_size=1, channels, height, width)
    b, c, h, w = tensor.size()
    features = tensor.view(c, h * w)      # reshape to (channels, height*width)
    G = torch.mm(features, features.t())  # compute Gram matrix (channels x channels)
    return G / (2 * c * h * w)  

# Load VGG19 model with pre-trained weights 
vgg = models.vgg19(weights=VGG19_Weights.DEFAULT).features.to(device).eval()
for param in vgg.parameters():
    param.requires_grad = False

#content_layer = ['conv4_2']
#style_layers = ['conv_1', 'conv_2', 'conv_3', 'conv_4', 'conv_5']

content_layer = '21' 
style_layers = ['0', '5', '10', '19', '28']

def get_content_feature(image):
    x = image
    for i, layer in enumerate(vgg):
        x = layer(x)
        if str(i) == content_layer:
            return x
        
def get_style_features(image, model, layers):
    features = []
    x = image
    for i, layer in enumerate(model):
        x = layer(x)
        if str(i) in layers:
            features.append(x)
    return features

def compute_content_loss(generated_features, content_features):
    return torch.nn.functional.mse_loss(generated_features, content_features)

def compute_style_loss(generated_features, style_features):
    loss = 0
    for gen_feat, style_feat in zip(generated_features, style_features):
        gram_generated = gram_matrix(gen_feat)
        gram_style = gram_matrix(style_feat)
        loss += torch.nn.functional.mse_loss(gram_generated, gram_style)
    return loss

def run_style_transfer(content_img_path, style_img_path, output_path, num_steps=300,
                    init_from_content=True,
                    snapshot_interval=50,
                    show_progress=True):
    
    # Load images 
    content_img = load_image(content_img_path)
    style_img = load_image(style_img_path)

    # Extract Content and Style features from both images, respectively 
    style_features = get_style_features(style_img, vgg, style_layers)
    content_features = get_content_feature(content_img)

    # Initialize generated image
    if init_from_content:
        generated_img = content_img.clone().to(device).requires_grad_(True)
    else:
        generated_img = torch.randn((1, 3, 512, 512), device=device, requires_grad=True)

    optimizer = optim.LBFGS([generated_img])

    # Loss tracking for graph plot
    losses = {"total": [], "content": [], "style": []}
    current_losses = {"total": None, "content": None, "style": None}
    snapshots = []       # sparse for plotting
    gif_frames = []      # dense for GIF
        
    def closure():
        optimizer.zero_grad()

        # Forward Pass
        gen_content = get_content_feature(generated_img)
        gen_style = get_style_features(generated_img, vgg, style_layers)

        # Compute style and content loss
        c_loss = compute_content_loss(gen_content, content_features)
        s_loss = compute_style_loss(gen_style, style_features)
        s_loss = (1e9*s_loss)

        total_loss = c_loss + s_loss
        total_loss.backward()

        current_losses["total"] = total_loss.item()
        current_losses["content"] = c_loss.item()
        current_losses["style"] = s_loss.item()

        return total_loss

    for step in range(num_steps):
        optimizer.step(closure)

        losses["total"].append(current_losses["total"])
        losses["content"].append(current_losses["content"])
        losses["style"].append(current_losses["style"])

        # GIF
        gif_frames.append(tensor_to_pil(generated_img.detach()))

        # Snapshot plots 
        if step % snapshot_interval == 0:
            snapshots.append(gif_frames[-1])

        if show_progress:
            print(f"Step {step}, Total Loss: {current_losses['total']:.4f}, "
            f"Content Loss: {current_losses['content']:.4f}, "
            f"Style Loss: {current_losses['style']:.4f}")
        
    # Save output 
    with torch.no_grad():
        final_img = generated_img.detach().clone()

    save_image(final_img, output_path)
    print(f"Saved stylised image to {output_path}")

    # Output loss plot and intermediate snapshots 
    plt.figure(figsize=(10, 5))
    steps = list(range(len(losses["total"])))
    plt.plot(steps, losses["total"], label="Total Loss")
    plt.plot(steps, losses["content"], label="Content Loss", alpha=0.7)
    plt.plot(steps, losses["style"], label="Style Loss", alpha=0.7)

    plt.yscale("log") 
    plt.xlabel("Steps")
    plt.ylabel("Loss (log scale)")
    plt.title("Neural Style Transfer Loss")
    plt.legend()
    plt.grid(True)

    plt.show()

    if snapshots:
        fig, axes = plt.subplots(1, len(snapshots), figsize=(15, 5))

        if len(snapshots) == 1:
            axes = [axes]

        for i, img in enumerate(snapshots):
            axes[i].imshow(img)
            axes[i].set_title(f"Step {i * snapshot_interval}")
            axes[i].axis("off")

        plt.tight_layout()
        plt.show()

    if gif_frames:
        gif_path = output_path.with_suffix(".gif")
        frames = [np.array(img) for img in gif_frames]
        imageio.mimsave(gif_path, frames, duration=0.08)
        print(f"Saved GIF to {gif_path}")

    return output_path

content_path=Path(r"ref_photos\stanford_uni.jpg")
style_path=Path(r"ref_paintings\Van_Gogh_-_Starry_Night_-_Google_Art_Project.jpg")
output_path=Path(r"generated_images\styled_new_method_van.jpg")

run_style_transfer(
    content_img_path=content_path,
    style_img_path=style_path, 
    output_path=output_path,
    num_steps=300,
    snapshot_interval=50,
    show_progress=True
)
# Out:
# cuda
# Step 0, Total Loss: 2541.1489, Content Loss: 71.7444, Style Loss: 2469.4045
# Step 1, Total Loss: 449.5813, Content Loss: 69.0051, Style Loss: 380.5762
# Step 2, Total Loss: 248.8470, Content Loss: 69.1693, Style Loss: 179.6777
# Step 3, Total Loss: 187.3675, Content Loss: 67.1254, Style Loss: 120.2421
# Step 4, Total Loss: 153.0456, Content Loss: 65.6516, Style Loss: 87.3940
# Step 5, Total Loss: 132.0125, Content Loss: 64.1045, Style Loss: 67.9081
# Step 6, Total Loss: 118.8858, Content Loss: 63.3096, Style Loss: 55.5762
# Step 7, Total Loss: 110.6108, Content Loss: 62.4830, Style Loss: 48.1278
# Step 8, Total Loss: 105.0894, Content Loss: 61.6587, Style Loss: 43.4307
# Step 9, Total Loss: 100.8581, Content Loss: 61.0070, Style Loss: 39.8511
# Step 10, Total Loss: 97.4726, Content Loss: 60.4877, Style Loss: 36.9850
# Step 11, Total Loss: 94.6845, Content Loss: 59.9986, Style Loss: 34.6858
# Step 12, Total Loss: 92.3285, Content Loss: 59.6138, Style Loss: 32.7147
# Step 13, Total Loss: 90.3948, Content Loss: 59.1587, Style Loss: 31.2361
# Step 14, Total Loss: 88.7589, Content Loss: 58.8691, Style Loss: 29.8898
# Step 15, Total Loss: 87.3262, Content Loss: 58.5666, Style Loss: 28.7595
# Step 16, Total Loss: 86.0291, Content Loss: 58.3635, Style Loss: 27.6656
# Step 17, Total Loss: 84.8849, Content Loss: 58.0954, Style Loss: 26.7895
# Step 18, Total Loss: 83.8939, Content Loss: 57.8803, Style Loss: 26.0136
# Step 19, Total Loss: 83.0540, Content Loss: 57.7352, Style Loss: 25.3187
# Step 20, Total Loss: 82.3022, Content Loss: 57.5140, Style Loss: 24.7882
# Step 21, Total Loss: 81.6561, Content Loss: 57.3100, Style Loss: 24.3460
# Step 22, Total Loss: 81.0365, Content Loss: 57.2036, Style Loss: 23.8330
# Step 23, Total Loss: 80.4972, Content Loss: 57.0652, Style Loss: 23.4321
# Step 24, Total Loss: 80.0093, Content Loss: 56.9404, Style Loss: 23.0689
# Step 25, Total Loss: 79.5719, Content Loss: 56.8052, Style Loss: 22.7667
# Step 26, Total Loss: 79.1462, Content Loss: 56.7050, Style Loss: 22.4412
# Step 27, Total Loss: 78.7568, Content Loss: 56.5743, Style Loss: 22.1825
# Step 28, Total Loss: 78.4148, Content Loss: 56.4514, Style Loss: 21.9634
# Step 29, Total Loss: 78.1054, Content Loss: 56.3921, Style Loss: 21.7132
# Step 30, Total Loss: 77.8002, Content Loss: 56.2992, Style Loss: 21.5011
# Step 31, Total Loss: 77.5352, Content Loss: 56.2368, Style Loss: 21.2985
# Step 32, Total Loss: 77.2812, Content Loss: 56.1498, Style Loss: 21.1313
# Step 33, Total Loss: 77.0301, Content Loss: 56.0692, Style Loss: 20.9609
# Step 34, Total Loss: 76.8207, Content Loss: 55.9902, Style Loss: 20.8305
# Step 35, Total Loss: 76.6055, Content Loss: 55.9378, Style Loss: 20.6677
# Step 36, Total Loss: 76.4102, Content Loss: 55.8873, Style Loss: 20.5229
# Step 37, Total Loss: 76.2236, Content Loss: 55.8128, Style Loss: 20.4107
# Step 38, Total Loss: 76.0481, Content Loss: 55.7500, Style Loss: 20.2981
# Step 39, Total Loss: 75.8880, Content Loss: 55.7025, Style Loss: 20.1855
# Step 40, Total Loss: 75.7206, Content Loss: 55.6426, Style Loss: 20.0780
# Step 41, Total Loss: 75.5782, Content Loss: 55.5882, Style Loss: 19.9900
# Step 42, Total Loss: 75.4298, Content Loss: 55.5379, Style Loss: 19.8919
# Step 43, Total Loss: 75.2928, Content Loss: 55.4921, Style Loss: 19.8007
# Step 44, Total Loss: 75.1626, Content Loss: 55.4546, Style Loss: 19.7080
# Step 45, Total Loss: 75.0348, Content Loss: 55.3967, Style Loss: 19.6381
# Step 46, Total Loss: 74.9176, Content Loss: 55.3609, Style Loss: 19.5567
# Step 47, Total Loss: 74.7977, Content Loss: 55.3116, Style Loss: 19.4861
# Step 48, Total Loss: 74.6929, Content Loss: 55.2765, Style Loss: 19.4164
# Step 49, Total Loss: 74.5862, Content Loss: 55.2362, Style Loss: 19.3500
# Step 50, Total Loss: 74.4804, Content Loss: 55.1961, Style Loss: 19.2843
# Step 51, Total Loss: 74.3830, Content Loss: 55.1684, Style Loss: 19.2146
# Step 52, Total Loss: 74.2928, Content Loss: 55.1281, Style Loss: 19.1646
# Step 53, Total Loss: 74.2036, Content Loss: 55.0943, Style Loss: 19.1093
# Step 54, Total Loss: 74.1231, Content Loss: 55.0652, Style Loss: 19.0579
# Step 55, Total Loss: 74.0412, Content Loss: 55.0373, Style Loss: 19.0039
# Step 56, Total Loss: 73.9653, Content Loss: 55.0009, Style Loss: 18.9644
# Step 57, Total Loss: 73.8949, Content Loss: 54.9715, Style Loss: 18.9234
# Step 58, Total Loss: 73.8205, Content Loss: 54.9457, Style Loss: 18.8748
# Step 59, Total Loss: 73.7547, Content Loss: 54.9202, Style Loss: 18.8345
# Step 60, Total Loss: 73.6888, Content Loss: 54.8971, Style Loss: 18.7917
# Step 61, Total Loss: 73.6235, Content Loss: 54.8723, Style Loss: 18.7512
# Step 62, Total Loss: 73.5630, Content Loss: 54.8485, Style Loss: 18.7145
# Step 63, Total Loss: 73.5016, Content Loss: 54.8250, Style Loss: 18.6766
# Step 64, Total Loss: 73.4458, Content Loss: 54.7992, Style Loss: 18.6466
# Step 65, Total Loss: 73.3913, Content Loss: 54.7796, Style Loss: 18.6118
# Step 66, Total Loss: 73.3397, Content Loss: 54.7609, Style Loss: 18.5788
# Step 67, Total Loss: 73.2858, Content Loss: 54.7373, Style Loss: 18.5485
# Step 68, Total Loss: 73.2365, Content Loss: 54.7146, Style Loss: 18.5219
# Step 69, Total Loss: 73.1881, Content Loss: 54.6983, Style Loss: 18.4899
# Step 70, Total Loss: 73.1412, Content Loss: 54.6773, Style Loss: 18.4639
# Step 71, Total Loss: 73.0967, Content Loss: 54.6612, Style Loss: 18.4355
# Step 72, Total Loss: 73.0534, Content Loss: 54.6423, Style Loss: 18.4111
# Step 73, Total Loss: 73.0122, Content Loss: 54.6251, Style Loss: 18.3871
# Step 74, Total Loss: 72.9715, Content Loss: 54.6087, Style Loss: 18.3628
# Step 75, Total Loss: 72.9341, Content Loss: 54.5922, Style Loss: 18.3419
# Step 76, Total Loss: 72.8971, Content Loss: 54.5781, Style Loss: 18.3190
# Step 77, Total Loss: 72.8631, Content Loss: 54.5614, Style Loss: 18.3018
# Step 78, Total Loss: 72.8285, Content Loss: 54.5516, Style Loss: 18.2769
# Step 79, Total Loss: 72.7946, Content Loss: 54.5342, Style Loss: 18.2604
# Step 80, Total Loss: 72.7606, Content Loss: 54.5203, Style Loss: 18.2403
# Step 81, Total Loss: 72.7285, Content Loss: 54.5090, Style Loss: 18.2195
# Step 82, Total Loss: 72.6975, Content Loss: 54.4962, Style Loss: 18.2013
# Step 83, Total Loss: 72.6674, Content Loss: 54.4851, Style Loss: 18.1823
# Step 84, Total Loss: 72.6379, Content Loss: 54.4710, Style Loss: 18.1669
# Step 85, Total Loss: 72.6096, Content Loss: 54.4582, Style Loss: 18.1514
# Step 86, Total Loss: 72.5826, Content Loss: 54.4480, Style Loss: 18.1346
# Step 87, Total Loss: 72.5560, Content Loss: 54.4379, Style Loss: 18.1181
# Step 88, Total Loss: 72.5306, Content Loss: 54.4263, Style Loss: 18.1042
# Step 89, Total Loss: 72.5067, Content Loss: 54.4149, Style Loss: 18.0918
# Step 90, Total Loss: 72.4820, Content Loss: 54.4062, Style Loss: 18.0758
# Step 91, Total Loss: 72.4586, Content Loss: 54.3949, Style Loss: 18.0636
# Step 92, Total Loss: 72.4360, Content Loss: 54.3853, Style Loss: 18.0507
# Step 93, Total Loss: 72.4135, Content Loss: 54.3749, Style Loss: 18.0386
# Step 94, Total Loss: 72.3920, Content Loss: 54.3658, Style Loss: 18.0263
# Step 95, Total Loss: 72.3707, Content Loss: 54.3598, Style Loss: 18.0108
# Step 96, Total Loss: 72.3506, Content Loss: 54.3504, Style Loss: 18.0002
# Step 97, Total Loss: 72.3312, Content Loss: 54.3421, Style Loss: 17.9891
# Step 98, Total Loss: 72.3120, Content Loss: 54.3322, Style Loss: 17.9798
# Step 99, Total Loss: 72.2936, Content Loss: 54.3245, Style Loss: 17.9691
# Step 100, Total Loss: 72.2754, Content Loss: 54.3182, Style Loss: 17.9572
# Step 101, Total Loss: 72.2574, Content Loss: 54.3135, Style Loss: 17.9440
# Step 102, Total Loss: 72.2403, Content Loss: 54.3031, Style Loss: 17.9372
# Step 103, Total Loss: 72.2236, Content Loss: 54.2987, Style Loss: 17.9249
# Step 104, Total Loss: 72.2063, Content Loss: 54.2894, Style Loss: 17.9169
# Step 105, Total Loss: 72.1899, Content Loss: 54.2836, Style Loss: 17.9063
# Step 106, Total Loss: 72.1734, Content Loss: 54.2756, Style Loss: 17.8979
# Step 107, Total Loss: 72.1578, Content Loss: 54.2704, Style Loss: 17.8874
# Step 108, Total Loss: 72.1422, Content Loss: 54.2618, Style Loss: 17.8804
# Step 109, Total Loss: 72.1268, Content Loss: 54.2556, Style Loss: 17.8711
# Step 110, Total Loss: 72.1117, Content Loss: 54.2503, Style Loss: 17.8614
# Step 111, Total Loss: 72.0968, Content Loss: 54.2440, Style Loss: 17.8528
# Step 112, Total Loss: 72.0825, Content Loss: 54.2376, Style Loss: 17.8448
# Step 113, Total Loss: 72.0681, Content Loss: 54.2316, Style Loss: 17.8366
# Step 114, Total Loss: 72.0541, Content Loss: 54.2241, Style Loss: 17.8300
# Step 115, Total Loss: 72.0405, Content Loss: 54.2179, Style Loss: 17.8225
# Step 116, Total Loss: 72.0268, Content Loss: 54.2125, Style Loss: 17.8143
# Step 117, Total Loss: 72.0138, Content Loss: 54.2099, Style Loss: 17.8039
# Step 118, Total Loss: 72.0008, Content Loss: 54.2034, Style Loss: 17.7973
# Step 119, Total Loss: 71.9875, Content Loss: 54.1980, Style Loss: 17.7894
# Step 120, Total Loss: 71.9747, Content Loss: 54.1917, Style Loss: 17.7830
# Step 121, Total Loss: 71.9625, Content Loss: 54.1844, Style Loss: 17.7781
# Step 122, Total Loss: 71.9503, Content Loss: 54.1803, Style Loss: 17.7700
# Step 123, Total Loss: 71.9386, Content Loss: 54.1725, Style Loss: 17.7661
# Step 124, Total Loss: 71.9268, Content Loss: 54.1695, Style Loss: 17.7573
# Step 125, Total Loss: 71.9155, Content Loss: 54.1634, Style Loss: 17.7521
# Step 126, Total Loss: 71.9044, Content Loss: 54.1595, Style Loss: 17.7448
# Step 127, Total Loss: 71.8939, Content Loss: 54.1546, Style Loss: 17.7394
# Step 128, Total Loss: 71.8838, Content Loss: 54.1514, Style Loss: 17.7324
# Step 129, Total Loss: 71.8737, Content Loss: 54.1462, Style Loss: 17.7275
# Step 130, Total Loss: 71.8638, Content Loss: 54.1438, Style Loss: 17.7200
# Step 131, Total Loss: 71.8539, Content Loss: 54.1377, Style Loss: 17.7162
# Step 132, Total Loss: 71.8443, Content Loss: 54.1340, Style Loss: 17.7103
# Step 133, Total Loss: 71.8349, Content Loss: 54.1300, Style Loss: 17.7049
# Step 134, Total Loss: 71.8258, Content Loss: 54.1258, Style Loss: 17.6999
# Step 135, Total Loss: 71.8167, Content Loss: 54.1229, Style Loss: 17.6938
# Step 136, Total Loss: 71.8078, Content Loss: 54.1195, Style Loss: 17.6883
# Step 137, Total Loss: 71.7990, Content Loss: 54.1148, Style Loss: 17.6842
# Step 138, Total Loss: 71.7907, Content Loss: 54.1114, Style Loss: 17.6793
# Step 139, Total Loss: 71.7826, Content Loss: 54.1068, Style Loss: 17.6758
# Step 140, Total Loss: 71.7743, Content Loss: 54.1041, Style Loss: 17.6702
# Step 141, Total Loss: 71.7665, Content Loss: 54.0995, Style Loss: 17.6670
# Step 142, Total Loss: 71.7589, Content Loss: 54.0984, Style Loss: 17.6605
# Step 143, Total Loss: 71.7509, Content Loss: 54.0926, Style Loss: 17.6583
# Step 144, Total Loss: 71.7436, Content Loss: 54.0897, Style Loss: 17.6539
# Step 145, Total Loss: 71.7363, Content Loss: 54.0875, Style Loss: 17.6488
# Step 146, Total Loss: 71.7288, Content Loss: 54.0836, Style Loss: 17.6453
# Step 147, Total Loss: 71.7218, Content Loss: 54.0797, Style Loss: 17.6421
# Step 148, Total Loss: 71.7146, Content Loss: 54.0783, Style Loss: 17.6364
# Step 149, Total Loss: 71.7077, Content Loss: 54.0741, Style Loss: 17.6336
# Step 150, Total Loss: 71.7007, Content Loss: 54.0722, Style Loss: 17.6285
# Step 151, Total Loss: 71.6939, Content Loss: 54.0681, Style Loss: 17.6258
# Step 152, Total Loss: 71.6871, Content Loss: 54.0653, Style Loss: 17.6218
# Step 153, Total Loss: 71.6802, Content Loss: 54.0610, Style Loss: 17.6192
# Step 154, Total Loss: 71.6732, Content Loss: 54.0588, Style Loss: 17.6144
# Step 155, Total Loss: 71.6667, Content Loss: 54.0560, Style Loss: 17.6106
# Step 156, Total Loss: 71.6600, Content Loss: 54.0524, Style Loss: 17.6075
# Step 157, Total Loss: 71.6533, Content Loss: 54.0506, Style Loss: 17.6027
# Step 158, Total Loss: 71.6470, Content Loss: 54.0467, Style Loss: 17.6003
# Step 159, Total Loss: 71.6402, Content Loss: 54.0431, Style Loss: 17.5970
# Step 160, Total Loss: 71.6338, Content Loss: 54.0400, Style Loss: 17.5937
# Step 161, Total Loss: 71.6279, Content Loss: 54.0380, Style Loss: 17.5899
# Step 162, Total Loss: 71.6214, Content Loss: 54.0344, Style Loss: 17.5870
# Step 163, Total Loss: 71.6152, Content Loss: 54.0311, Style Loss: 17.5841
# Step 164, Total Loss: 71.6094, Content Loss: 54.0288, Style Loss: 17.5805
# Step 165, Total Loss: 71.6034, Content Loss: 54.0259, Style Loss: 17.5775
# Step 166, Total Loss: 71.5977, Content Loss: 54.0243, Style Loss: 17.5734
# Step 167, Total Loss: 71.5922, Content Loss: 54.0206, Style Loss: 17.5716
# Step 168, Total Loss: 71.5863, Content Loss: 54.0194, Style Loss: 17.5669
# Step 169, Total Loss: 71.5808, Content Loss: 54.0166, Style Loss: 17.5642
# Step 170, Total Loss: 71.5752, Content Loss: 54.0135, Style Loss: 17.5616
# Step 171, Total Loss: 71.5701, Content Loss: 54.0115, Style Loss: 17.5586
# Step 172, Total Loss: 71.5646, Content Loss: 54.0091, Style Loss: 17.5555
# Step 173, Total Loss: 71.5591, Content Loss: 54.0077, Style Loss: 17.5515
# Step 174, Total Loss: 71.5540, Content Loss: 54.0047, Style Loss: 17.5493
# Step 175, Total Loss: 71.5488, Content Loss: 54.0028, Style Loss: 17.5461
# Step 176, Total Loss: 71.5434, Content Loss: 54.0010, Style Loss: 17.5424
# Step 177, Total Loss: 71.5383, Content Loss: 53.9979, Style Loss: 17.5404
# Step 178, Total Loss: 71.5332, Content Loss: 53.9967, Style Loss: 17.5365
# Step 179, Total Loss: 71.5283, Content Loss: 53.9946, Style Loss: 17.5337
# Step 180, Total Loss: 71.5233, Content Loss: 53.9914, Style Loss: 17.5320
# Step 181, Total Loss: 71.5185, Content Loss: 53.9905, Style Loss: 17.5280
# Step 182, Total Loss: 71.5138, Content Loss: 53.9861, Style Loss: 17.5277
# Step 183, Total Loss: 71.5087, Content Loss: 53.9841, Style Loss: 17.5246
# Step 184, Total Loss: 71.5043, Content Loss: 53.9838, Style Loss: 17.5205
# Step 185, Total Loss: 71.4995, Content Loss: 53.9816, Style Loss: 17.5179
# Step 186, Total Loss: 71.4990, Content Loss: 53.9811, Style Loss: 17.5178
# Step 187, Total Loss: 71.4944, Content Loss: 53.9804, Style Loss: 17.5140
# Step 188, Total Loss: 71.4900, Content Loss: 53.9776, Style Loss: 17.5124
# Step 189, Total Loss: 71.4858, Content Loss: 53.9757, Style Loss: 17.5101
# Step 190, Total Loss: 71.4829, Content Loss: 53.9749, Style Loss: 17.5080
# Step 191, Total Loss: 71.4784, Content Loss: 53.9731, Style Loss: 17.5053
# Step 192, Total Loss: 71.4742, Content Loss: 53.9697, Style Loss: 17.5045
# Step 193, Total Loss: 71.4699, Content Loss: 53.9695, Style Loss: 17.5004
# Step 194, Total Loss: 71.4655, Content Loss: 53.9671, Style Loss: 17.4984
# Step 195, Total Loss: 71.4628, Content Loss: 53.9655, Style Loss: 17.4974
# Step 196, Total Loss: 71.4586, Content Loss: 53.9655, Style Loss: 17.4931
# Step 197, Total Loss: 71.4545, Content Loss: 53.9642, Style Loss: 17.4903
# Step 198, Total Loss: 71.4505, Content Loss: 53.9622, Style Loss: 17.4883
# Step 199, Total Loss: 71.4468, Content Loss: 53.9604, Style Loss: 17.4864
# Step 200, Total Loss: 71.4426, Content Loss: 53.9590, Style Loss: 17.4836
# Step 201, Total Loss: 71.4388, Content Loss: 53.9562, Style Loss: 17.4826
# Step 202, Total Loss: 71.4349, Content Loss: 53.9554, Style Loss: 17.4795
# Step 203, Total Loss: 71.4337, Content Loss: 53.9551, Style Loss: 17.4786
# Step 204, Total Loss: 71.4321, Content Loss: 53.9551, Style Loss: 17.4770
# Step 205, Total Loss: 71.4281, Content Loss: 53.9542, Style Loss: 17.4739
# Step 206, Total Loss: 71.4242, Content Loss: 53.9523, Style Loss: 17.4719
# Step 207, Total Loss: 71.4204, Content Loss: 53.9502, Style Loss: 17.4703
# Step 208, Total Loss: 71.4176, Content Loss: 53.9484, Style Loss: 17.4691
# Step 209, Total Loss: 71.4140, Content Loss: 53.9472, Style Loss: 17.4668
# Step 210, Total Loss: 71.4112, Content Loss: 53.9471, Style Loss: 17.4641
# Step 211, Total Loss: 71.4078, Content Loss: 53.9436, Style Loss: 17.4641
# Step 212, Total Loss: 71.4041, Content Loss: 53.9436, Style Loss: 17.4606
# Step 213, Total Loss: 71.4003, Content Loss: 53.9410, Style Loss: 17.4593
# Step 214, Total Loss: 71.3967, Content Loss: 53.9391, Style Loss: 17.4576
# Step 215, Total Loss: 71.3931, Content Loss: 53.9379, Style Loss: 17.4552
# Step 216, Total Loss: 71.3909, Content Loss: 53.9365, Style Loss: 17.4544
# Step 217, Total Loss: 71.3872, Content Loss: 53.9339, Style Loss: 17.4533
# Step 218, Total Loss: 71.3838, Content Loss: 53.9331, Style Loss: 17.4507
# Step 219, Total Loss: 71.3799, Content Loss: 53.9312, Style Loss: 17.4487
# Step 220, Total Loss: 71.3765, Content Loss: 53.9269, Style Loss: 17.4496
# Step 221, Total Loss: 71.3730, Content Loss: 53.9269, Style Loss: 17.4461
# Step 222, Total Loss: 71.3694, Content Loss: 53.9260, Style Loss: 17.4434
# Step 223, Total Loss: 71.3660, Content Loss: 53.9236, Style Loss: 17.4423
# Step 224, Total Loss: 71.3625, Content Loss: 53.9237, Style Loss: 17.4388
# Step 225, Total Loss: 71.3590, Content Loss: 53.9217, Style Loss: 17.4374
# Step 226, Total Loss: 71.3556, Content Loss: 53.9207, Style Loss: 17.4349
# Step 227, Total Loss: 71.3553, Content Loss: 53.9205, Style Loss: 17.4348
# Step 228, Total Loss: 71.3519, Content Loss: 53.9191, Style Loss: 17.4328
# Step 229, Total Loss: 71.3486, Content Loss: 53.9162, Style Loss: 17.4324
# Step 230, Total Loss: 71.3451, Content Loss: 53.9149, Style Loss: 17.4302
# Step 231, Total Loss: 71.3435, Content Loss: 53.9151, Style Loss: 17.4284
# Step 232, Total Loss: 71.3401, Content Loss: 53.9136, Style Loss: 17.4264
# Step 233, Total Loss: 71.3386, Content Loss: 53.9121, Style Loss: 17.4265
# Step 234, Total Loss: 71.3354, Content Loss: 53.9108, Style Loss: 17.4246
# Step 235, Total Loss: 71.3323, Content Loss: 53.9093, Style Loss: 17.4231
# Step 236, Total Loss: 71.3293, Content Loss: 53.9080, Style Loss: 17.4213
# Step 237, Total Loss: 71.3260, Content Loss: 53.9061, Style Loss: 17.4199
# Step 238, Total Loss: 71.3251, Content Loss: 53.9067, Style Loss: 17.4184
# Step 239, Total Loss: 71.3220, Content Loss: 53.9043, Style Loss: 17.4177
# Step 240, Total Loss: 71.3203, Content Loss: 53.9027, Style Loss: 17.4176
# Step 241, Total Loss: 71.3173, Content Loss: 53.9020, Style Loss: 17.4152
# Step 242, Total Loss: 71.3142, Content Loss: 53.8996, Style Loss: 17.4147
# Step 243, Total Loss: 71.3139, Content Loss: 53.8990, Style Loss: 17.4149
# Step 244, Total Loss: 71.3113, Content Loss: 53.8994, Style Loss: 17.4120
# Step 245, Total Loss: 71.3101, Content Loss: 53.8987, Style Loss: 17.4114
# Step 246, Total Loss: 71.3073, Content Loss: 53.8984, Style Loss: 17.4088
# Step 247, Total Loss: 71.3042, Content Loss: 53.8971, Style Loss: 17.4070
# Step 248, Total Loss: 71.3015, Content Loss: 53.8955, Style Loss: 17.4060
# Step 249, Total Loss: 71.2984, Content Loss: 53.8935, Style Loss: 17.4049
# Step 250, Total Loss: 71.2955, Content Loss: 53.8938, Style Loss: 17.4017
# Step 251, Total Loss: 71.2936, Content Loss: 53.8919, Style Loss: 17.4017
# Step 252, Total Loss: 71.2911, Content Loss: 53.8921, Style Loss: 17.3990
# Step 253, Total Loss: 71.2881, Content Loss: 53.8905, Style Loss: 17.3977
# Step 254, Total Loss: 71.2852, Content Loss: 53.8889, Style Loss: 17.3963
# Step 255, Total Loss: 71.2823, Content Loss: 53.8861, Style Loss: 17.3962
# Step 256, Total Loss: 71.2798, Content Loss: 53.8858, Style Loss: 17.3940
# Step 257, Total Loss: 71.2767, Content Loss: 53.8849, Style Loss: 17.3918
# Step 258, Total Loss: 71.2741, Content Loss: 53.8831, Style Loss: 17.3911
# Step 259, Total Loss: 71.2713, Content Loss: 53.8817, Style Loss: 17.3896
# Step 260, Total Loss: 71.2709, Content Loss: 53.8805, Style Loss: 17.3903
# Step 261, Total Loss: 71.2685, Content Loss: 53.8802, Style Loss: 17.3883
# Step 262, Total Loss: 71.2658, Content Loss: 53.8791, Style Loss: 17.3867
# Step 263, Total Loss: 71.2631, Content Loss: 53.8781, Style Loss: 17.3850
# Step 264, Total Loss: 71.2604, Content Loss: 53.8762, Style Loss: 17.3842
# Step 265, Total Loss: 71.2574, Content Loss: 53.8739, Style Loss: 17.3835
# Step 266, Total Loss: 71.2565, Content Loss: 53.8754, Style Loss: 17.3811
# Step 267, Total Loss: 71.2540, Content Loss: 53.8744, Style Loss: 17.3796
# Step 268, Total Loss: 71.2518, Content Loss: 53.8726, Style Loss: 17.3791
# Step 269, Total Loss: 71.2492, Content Loss: 53.8723, Style Loss: 17.3769
# Step 270, Total Loss: 71.2465, Content Loss: 53.8706, Style Loss: 17.3759
# Step 271, Total Loss: 71.2443, Content Loss: 53.8685, Style Loss: 17.3758
# Step 272, Total Loss: 71.2415, Content Loss: 53.8682, Style Loss: 17.3734
# Step 273, Total Loss: 71.2390, Content Loss: 53.8651, Style Loss: 17.3738
# Step 274, Total Loss: 71.2364, Content Loss: 53.8636, Style Loss: 17.3728
# Step 275, Total Loss: 71.2341, Content Loss: 53.8622, Style Loss: 17.3719
# Step 276, Total Loss: 71.2316, Content Loss: 53.8615, Style Loss: 17.3701
# Step 277, Total Loss: 71.2291, Content Loss: 53.8605, Style Loss: 17.3686
# Step 278, Total Loss: 71.2270, Content Loss: 53.8590, Style Loss: 17.3679
# Step 279, Total Loss: 71.2243, Content Loss: 53.8592, Style Loss: 17.3651
# Step 280, Total Loss: 71.2221, Content Loss: 53.8571, Style Loss: 17.3650
# Step 281, Total Loss: 71.2197, Content Loss: 53.8567, Style Loss: 17.3630
# Step 282, Total Loss: 71.2174, Content Loss: 53.8553, Style Loss: 17.3621
# Step 283, Total Loss: 71.2151, Content Loss: 53.8547, Style Loss: 17.3604
# Step 284, Total Loss: 71.2127, Content Loss: 53.8536, Style Loss: 17.3591
# Step 285, Total Loss: 71.2105, Content Loss: 53.8521, Style Loss: 17.3585
# Step 286, Total Loss: 71.2080, Content Loss: 53.8505, Style Loss: 17.3575
# Step 287, Total Loss: 71.2056, Content Loss: 53.8503, Style Loss: 17.3553
# Step 288, Total Loss: 71.2048, Content Loss: 53.8497, Style Loss: 17.3551
# Step 289, Total Loss: 71.2027, Content Loss: 53.8490, Style Loss: 17.3537
# Step 290, Total Loss: 71.2006, Content Loss: 53.8474, Style Loss: 17.3532
# Step 291, Total Loss: 71.2005, Content Loss: 53.8481, Style Loss: 17.3524
# Step 292, Total Loss: 71.1993, Content Loss: 53.8474, Style Loss: 17.3519
# Step 293, Total Loss: 71.1970, Content Loss: 53.8457, Style Loss: 17.3513
# Step 294, Total Loss: 71.1964, Content Loss: 53.8466, Style Loss: 17.3499
# Step 295, Total Loss: 71.1943, Content Loss: 53.8444, Style Loss: 17.3499
# Step 296, Total Loss: 71.1920, Content Loss: 53.8434, Style Loss: 17.3486
# Step 297, Total Loss: 71.1897, Content Loss: 53.8433, Style Loss: 17.3464
# Step 298, Total Loss: 71.1875, Content Loss: 53.8414, Style Loss: 17.3461
# Step 299, Total Loss: 71.1872, Content Loss: 53.8411, Style Loss: 17.3462
# Saved stylised image to generated_images\styled_new_method_van.jpg
# Saved GIF to generated_images\styled_new_method_van.gif
# WindowsPath('generated_images/styled_new_method_van.jpg')
